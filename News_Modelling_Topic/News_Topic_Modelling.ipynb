# %% [markdown]
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Reference:**
#
# > https://www.machinelearningplus.com/nlp/topic-modeling-gensim-python/#2prerequisitesdownloadnltkstopwordsandspacymodelforlemmatization

# %% [markdown]
#  ---

# %% [markdown]
# __Import the modules__

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import os
import glob
from datetime import datetime
import string
from collections import Counter
from tqdm import tqdm, notebook
tqdm.pandas()

# don't display warnings info
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# Gensim
# !pip install --upgrade gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.models.wrappers import LdaMallet
# set the environment for mallet
os.environ.update({'MALLET_HOME':r'C:\Users\Willa\OneDrive\Desktop\mallet-2.0.8'})
mallet_path = r'C:\Users\Willa\OneDrive\Desktop\mallet-2.0.8\bin\mallet'# update this path

# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

# Nltk for text processing
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk import pos_tag
from nltk.corpus import wordnet
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('punkt')

# spacy for lemmatization
import spacy


# model storage
import pickle
import joblib
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Import Datasets

# %% [markdown]
# __Read the scraped FOX News__

# %%
fox_coronav = pd.read_excel('/content/drive/My Drive/News_Fox_CNN/foxnews_article_form.xlsx')
fox_coronav.head()
# Out:
#              true_time  ...                                            content
# 0  2020-04-09 00:00:00  ...  The wife of Edmonton Oilers forward Colby Cave...
# 1  2020-04-09 00:00:00  ...  The body of 8-year-old Gideon McKean was recov...
# 2  2020-04-09 00:00:00  ...  Get all the latest news on coronavirus and mor...
# 3  2020-04-09 00:00:00  ...  Get all the latest news on coronavirus and mor...
# 4  2020-04-09 00:00:00  ...  Get all the latest news on coronavirus and mor...
#
# [5 rows x 5 columns]

# %%
# drop the nulls, transform the datatime type
fox_coronav = fox_coronav.dropna()
date = datetime.strptime('2020-1-22', '%Y-%m-%d')
df1 = fox_coronav.loc[fox_coronav['true_time']> date,:]

# %%
# rearrange the columns 
col = ['true_time', 'headline', 'content', 'link']
df1 = df1[col]
df1['platform'] = 'fox'
df1.head()
# Out:
#              true_time  ... platform
# 0  2020-04-09 00:00:00  ...      fox
# 1  2020-04-09 00:00:00  ...      fox
# 2  2020-04-09 00:00:00  ...      fox
# 3  2020-04-09 00:00:00  ...      fox
# 4  2020-04-09 00:00:00  ...      fox
#
# [5 rows x 5 columns]

# %% [markdown]
# __Read the scraped CNN News__

# %%
cnn_coronav = pd.read_excel('CNN_covid-19_0408.xlsx').drop(['Unnamed: 0'], axis = 1)
cnn_coronav = cnn_coronav.dropna()
date = datetime.strptime('2020-1-22', '%Y-%m-%d')
cnn_coronav['published'] = cnn_coronav.published_date.apply(lambda x : datetime.strptime(x, '%b %d, %Y'))
df2 = cnn_coronav.loc[cnn_coronav['published']> date,:]
col2 = ['published', 'headline', 'content', 'link']
df2 = df2[col2]
df2.columns = col
df2['platform'] = 'cnn'
df2.head()
# Out:
#    true_time  ... platform
# 0 2020-04-08  ...      cnn
# 1 2020-04-08  ...      cnn
# 2 2020-04-08  ...      cnn
# 3 2020-04-06  ...      cnn
# 4 2020-04-05  ...      cnn
#
# [5 rows x 5 columns]

# %% [markdown]
# __Combine CNN News and FOX News__

# %%
df = pd.concat([df1, df2], axis = 0)
df = df.sort_values('true_time').reset_index(drop = False)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-833cd775c49a> in <module>()
# ----> 1 df = pd.concat([df1, df2], axis = 0)
#       2 df = df.sort_values('true_time').reset_index(drop = False)
#       3 df.head()
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ## Clean the texts in 'content' column
#
# Since the scraped news contain advertising 'stop sentences' like __'Sign up here'__ and __'Check out for latest hot headlines'__. We should first delete these sentences, then head to the domain of text cleaning.

# %%
# check for duplicated rows 
df[df.duplicated(subset = 'content')]
# Out:
# Empty DataFrame
# Columns: [index, true_time, headline, content, link, platform]
# Index: []

# %%
# drop the duplicated rows 
df.drop_duplicates(subset = 'content', inplace = True)

# %% [markdown]
# __Check the 'stop sentences'__

# %%
all_news = ' '.join(''.join(df['content']).split('\xa0')) #exclude \xa0
all_news_sentences = sent_tokenize(all_news) # get all the sentences
Counter(all_news_sentences).most_common()
# Out:
# [('All rights reserved.', 1734),
#  ('©2020 FOX News Network, LLC.', 1725),
#  ('This material may not be published, broadcast, rewritten, or redistributed.',
#   1636),
#  ('Sign up here.', 1346),
#  ('All market data delayed 20 minutes.Get all the latest news on coronavirus and more delivered daily to your inbox.',
#   1285),
#  ("Get all the stories you need-to-know from the most powerful name in news delivered first thing every morning to your inbox Subscribed You've successfully subscribed to this newsletter!",
#   785),
#  ("Check out what's clicking on Foxnews.com.", 685),
#  ("Subscribed You've successfully subscribed to this newsletter!", 402),
#  ("Check out what's clicking today in entertainment.", 379),
#  ('The Associated Press contributed to this report.', 252),
#  ('Gov.', 124),
#  ('GUTFELD: Yes.', 117),
#  ('...', 111),
#  ('Fun stories about food, relationships, the great outdoors and more.', 106),
#  ('All market data delayed 20 minutes.', 103),
#  ('Fox News Flash top headlines are here.', 85),
#  ('Thank you.', 83),
#  ('Stay up-to-date on the biggest health and wellness news with our weekly recap.',
#   75),
#  ('Take a look.', 71),
#  ('For some, especially older adults and people with existing health problems, it can cause more severe illness, including pneumonia.',
#   70),
#  ('Get all the latest news on coronavirus and more delivered daily to your inbox.',
#   66),
#  ('Watch the latest videos on Covid-19.', 63),
#  ('New York Gov.', 61),
#  ('Watch.', 58),
#  ('"Fox News Flash top headlines are here.', 57),
#  ('ET.', 56),
#  ('Bret.', 55),
#  ('Why?', 54),
#  ('HOW DANGEROUS IS CORONAVIRUS?', 53),
#  ('No.', 51),
#  ('Fox News Flash top entertainment and celebrity headlines are here.', 50),
#  ('All right.', 43),
#  ('Click here for more.', 41),
#  ('Yes.', 41),
#  ('2.', 40),
#  ("Oz Show' host Dr. Mehmet Oz joins Harris Faulkner to discuss the coronavirus outbreak on 'Outnumbered Overtime.'",
#   40),
#  ('3.', 39),
#  ('California Gov.', 38),
#  ('MACCALLUM: Yes.', 37),
#  ('Get a daily look at what’s developing in science and technology throughout the world.',
#   37),
#  ('The Associated Press contributed to this report.Fox News Flash top headlines are here.',
#   34),
#  ('4.', 34),
#  ('For most people, the new coronavirus causes only mild or moderate symptoms, such as fever and cough.',
#   34),
#  ("We'll be right back.", 33),
#  ('WHAT COUNTRIES HAVE NOT DECLARED ANY KNOWN CASES OF CORONAVIRUS?', 30),
#  ('He joins us tonight.', 29),
#  ('Watch this.', 29),
#  ('5.', 28),
#  ('1.', 28),
#  ('The Associated Press contributed to this report.Fox News Flash top entertainment and celebrity headlines are here.',
#   28),
#  ('Right?', 27),
#  ('Read more here.', 27),
#  ('BARTIROMO: Yes.', 26),
#  ('"Fox News Flash top entertainment and celebrity headlines are here.', 26),
#  ('HANNITY: All right.', 26),
#  ('(Fox News behind the scenes at the town hall.)', 26),
#  ('#TheFlashback: CLICK HERE to find out what happened on "This Day in History."',
#   25),
#  ("Click here to find out what you're missing.", 25),
#  ('Thank you for making us your first choice in the morning!', 25),
#  ('CAVUTO: Right.', 25),
#  ('For most people, the new coronavirus causes only mild or moderate symptoms.',
#   25),
#  ('Not signed up yet for Fox News First?', 24),
#  ("Fox News First is compiled by Fox News' Bryan Robinson.", 24),
#  ('Okay.', 24),
#  ('What do you think?', 24),
#  ('The vast majority of people recover from the new virus.', 24),
#  ('GET THE FOX NEWS APP Get a daily look at what’s developing in science and technology throughout the world.',
#   24),
#  ('LIMITED TIME OFFER, GET YOUR FIRST MONTH OF FOX NATION FOR $0.99 Fox Nation programs are viewable on-demand and from your mobile device app, but only for Fox Nation subscribers.',
#   23),
#  ('Bret?', 22),
#  ('Click here for more on our top story.', 22),
#  ('CAVUTO: All right.', 21),
#  ('Right.', 20),
#  ('Enjoy your day!', 20),
#  ("Click here to find out what's on Fox News and Fox News Radio today!", 20),
#  ('According to the World Health Organization, people with mild illness recover in about two weeks, while those with more severe illness may take three to six weeks to recover.',
#   20),
#  ('Thank you very much.', 19),
#  ('Stay with us.', 19),
#  ('Florida Gov.', 19),
#  ('Illinois Gov.', 19),
#  ('CARLSON: Yes.', 18),
#  ('he asked.', 18),
#  ('Andrew Cuomo.', 18),
#  ('Q.', 18),
#  ('Maryland Gov.', 18),
#  ('GOV.', 17),
#  ('Our live coverage of the coronavirus pandemic has moved here.', 17),
#  ('For some it can cause more severe illness.', 17),
#  ('For some others, especially older adults and people with existing health problems, it could cause more severe illness, including pneumonia.',
#   17),
#  ('The new coronavirus causes mild or moderate symptoms for most people, but for some, especially older adults and people with existing health problems, it can cause more severe illness or death.',
#   17),
#  ("Fox News' Alexandria Hein contributed to this report.", 16),
#  ('To hear the full interview, subscribe and download The FOX News Rundown on your favorite podcast player.',
#   16),
#  ("I don't know.", 16),
#  ('Read the full story here.', 16),
#  ('.', 16),
#  ('The vast majority of people recover.', 16),
#  ('GUTFELD: Right.', 15),
#  ('Follow James Rogers on Twitter @jamesjrogers Get a daily look at what’s developing in science and technology throughout the world.',
#   15),
#  ('Want the Fox News Rundown sent straight to your mobile device?', 14),
#  ('Subscribe through Apple Podcasts, Google Play, and Stitcher.', 14),
#  ('The Brian Kilmeade Show, 9 a.m.', 14),
#  ('GRAHAM: Right.', 14),
#  ('OK.', 14),
#  ('Michigan Gov.', 14),
#  ('It comes from China.', 14),
#  ('The total includes cases from all 50 states, the District of Columbia and other US territories, as well as all repatriated cases.',
#   14),
#  ('OK?', 13),
#  ('Absolutely.', 13),
#  ('Washington Gov.', 13),
#  ('she said.', 13),
#  ('YOU ASKED.', 13),
#  ('Listen now.', 13),
#  ('For some, especially older adults and people with existing health problems, it can cause more severe illness, including pneumonia and death.',
#   13),
#  ('CLICK HERE TO GET THE FOX NEWS APP This material may not be published, broadcast, rewritten, or redistributed.',
#   13),
#  ("I'm Bret Baier.", 12),
#  ('Hey, Trace.', 12),
#  ("That's next.", 12),
#  ('I appreciate it.', 12),
#  ('Good to see you.', 12),
#  ('HOW IS CORONAVIRUS TRANSMITTED?', 12),
#  ('(COMMERCIAL BREAK)  BARTIROMO: Welcome back.', 12),
#  ("Check out what's clicking on FoxNews.com.", 12),
#  ('Good evening.', 12),
#  ('WHAT HAPPENS AFTER YOU GET OVER THE CORONAVIRUS?', 12),
#  ('Make public your data!', 12),
#  ('Send yours here.', 12),
#  ('A version of this article first appeared in the "Reliable Sources" newsletter.',
#   12),
#  ('CORONAVIRUS VACCINE DEVELOPMENT: WHERE DOES IT STAND?', 12),
#  ('Go to Fox Nation today to start a free trial and watch the extensive library from Tomi Lahren, Pete Hegseth, Abby Hornacek, Laura Ingraham, Ainsley Earhardt, Greg Gutfeld, Judge Andrew Napolitano and many more of your favorite Fox News personalities.',
#   12),
#  ('The Associated Press contributed to this article.', 12),
#  ('Originally published on Live Science.', 12),
#  ('Doctor, thanks so much for coming on.', 11),
#  ('The Associated Press contributed to this report.Dr.', 11),
#  ('GUTFELD: Exactly.', 11),
#  ('WATTERS: Yes.', 11),
#  ('GUTFELD: Yeah.', 11),
#  ('You can sign up for free right here.', 11),
#  ('he said.', 11),
#  ('“The Prince of Wales has tested positive for Coronavirus.', 11),
#  ('I loved being read to as a child, and I remember Mrs. Laura Bush encouraging families to keep a story time routine with children as much as possible, especially during times of stress and uncertainty.',
#   11),
#  ('I hope that parents will be able to take a breather while I try to keep their kids occupied and entertained for a few minutes every day.',
#   11),
#  ('Get the recap of top opinion commentary and original content throughout the week.',
#   11),
#  ('Period.', 10),
#  ('GUTFELD: No.', 10),
#  ('No deaths have been reported in the U.S., and the large majority of cases still remain in China.',
#   10),
#  ('Please.', 10),
#  ('Thanks so much.', 10),
#  ('Our live coverage of the coronavirus outbreak has moved here.', 10),
#  ('U.S.', 10),
#  ('CAVUTO: Yes.', 10),
#  ('6.', 10),
#  ("They couldn't do it.", 10),
#  ('This includes presumptive positive cases that tested positive in a public health lab and are pending confirmation from the CDC, and confirmed cases have received positive results from the CDC.',
#   10),
#  ("Note: The prices above reflect the retailer's listed price at the time of publication.",
#   10),
#  ('PAYNE: Right.', 10),
#  ('Ohio Gov.', 10),
#  ('Listen to the CNN Coronavirus: Fact vs. Fiction podcast with chief medical correspondent Dr. Sanjay Gupta here.',
#   10),
#  ('Louisiana Gov.', 10),
#  ('WHY DO SOME COUNTRIES STILL HAVE NEXT TO NO RECORDED OUTBREAKS OF CORONAVIRUS?',
#   10),
#  ('It comes from China."', 10),
#  ("CARLSON: That's right.", 9),
#  ('DO SURGICAL MASKS PROTECT AGAINST CORONAVIRUS?', 9),
#  ('Why not?', 9),
#  ("That's it.", 9),
#  ('WILLIAMS: All right.', 9),
#  ('What?', 9),
#  ('Trump tweeted.', 9),
#  ('Fox News medical contributor Dr. Nicole Saphier weighs in.', 9),
#  ('At CNN, we start with the facts.', 9),
#  ("Visit CNN's home for Facts First.", 9),
#  ('WE ANSWERED.', 9),
#  ('Andrew Cuomo said.', 9),
#  ('(You can also get "5 Things You Need to Know Today" delivered to your inbox daily.',
#   9),
#  ('Sign up here.)', 9),
#  ('Additionally, there would be $500 payments for each child.', 9),
#  ('NBA Commissioner Adam Silver comments on how the pandemic may have altered the league’s calendar permanently.',
#   9),
#  ('Fiction."', 9),
#  ('For most people, the new coronavirus causes mild or moderate symptoms, such as fever and cough that clear up in two to three weeks.',
#   9),
#  ('“FOX Presents the IHeart Living Room Concert for America” will air on Sunday at 9 p.m.',
#   9),
#  ('The most recent invoice from the WHO to the United States, which is one of many countries that fund the organization, was for nearly $116 million per year.',
#   9),
#  ('Exactly.', 8),
#  ('Great to see you.', 8),
#  ('ALL RIGHTS RESERVED.', 8),
#  ('Who knows?', 8),
#  ('I get it.', 8),
#  ('WATTERS: Yeah.', 8),
#  ('Welcome, everybody.', 8),
#  ('The U.S. State Department raised its China travel advisory to "Level 4: Do Not Travel."',
#   8),
#  ('Thank you so much.', 8),
#  ('Appreciate it.', 8),
#  ('HEGSETH: Yes.', 8),
#  ('INGRAHAM: Yes.', 8),
#  ("I'm Neil Cavuto.", 8),
#  ('Wow.', 8),
#  ('We did one of the great jobs.', 8),
#  ('They have no clue.', 8),
#  ("President, they tried to beat you on Russia, Russia, Russia, that didn't work out too well.",
#   8),
#  ('Marc Lipsitch, infectious disease epidemiologist at Harvard University, predicts that the coronavirus will ultimately not be containable.',
#   8),
#  ('What digital lifestyle questions do you have?', 8),
#  ('Copyright 2020, WestStar Multimedia Entertainment.', 8),
#  ('Gavin Newsom.', 8),
#  ("CORONAVIRUS CONCERNS CAUSE 'JEOPARDY!'", 8),
#  ('CLICK HERE TO GET THE FOX NEWS APPFox News Flash top headlines are here.',
#   8),
#  ('How many people are infected?', 8),
#  ('Be transparent!', 8),
#  ('she asked.', 8),
#  ('For most people, the new coronavirus has caused only mild or moderate symptoms, such as fever and cough.',
#   8),
#  ('The second response bill that was signed into law Wednesday aims to bring relief to workers who lost their jobs and families at home for illnesses, quarantines or caring for kids whose schools have shuttered.',
#   8),
#  ('CORONAVIRUS QUESTIONS ANSWERED: CAN YOU HAVE FLU AND COVID-19 AT SAME TIME?',
#   8),
#  ('Texas Gov.', 8),
#  ('They would be phased down at adjusted gross income thresholds of $75,000 for individuals and $150,000 per couple.',
#   8),
#  ('The amount is reduced to zero for single taxpayers with incomes exceeding $99,000 and $198,000 for joint filers.',
#   8),
#  ("I'm Dr. Sanjay Gupta, CNN's Chief Medical Correspondent.", 8),
#  ('Thanks for listening.', 8),
#  ('“Her Majesty The Queen remains in good health.', 8),
#  ('The Queen last saw the Prince of Wales briefly after the investiture on the morning of the 12th of March and is following all the appropriate advice with regard to her welfare," the spokesman said.',
#   8),
#  ('New Jersey Gov.', 8),
#  ('The United States is the single largest contributor to the WHO.', 8),
#  ('The WHO&aposs total budget for 2016 and 2017 combined was over $4 billion.',
#   8),
#  ('Mike, thanks.', 7),
#  ('BAIER: Yes.', 7),
#  ('Great to see you tonight.', 7),
#  ('But you know what?', 7),
#  ('WATTERS: All right.', 7),
#  ('Go ahead.', 7),
#  ('More after this.', 7),
#  ('CAVUTO: Got it.', 7),
#  ('Go to Fox Nation to start a free trial and watch the extensive library from Tomi Lahren, Pete Hegseth, Abby Hornacek, Laura Ingraham, Ainsley Earhardt, Greg Gutfeld, Judge Andrew Napolitano and many more of your favorite Fox News personalities.',
#   7),
#  ('Stay tuned.', 7),
#  ('WILLIAMS: No.', 7),
#  ('How many have been infected or have died?', 7),
#  ("Singapore said it would ban travelers from China's Hubei province.", 7),
#  ('They also blocked tour groups from China.', 7),
#  ('Hong Kong reduced half its flights and shut down rail service to mainland China.',
#   7),
#  ('Air Canada suspending all direct flights to Beijing and Shanghai.', 7),
#  ('Thank you, Tucker.', 7),
#  ('MACCALLUM: All right.', 7),
#  ('INGRAHAM: All right.', 7),
#  ('There you go.', 7),
#  ('The FOX NEWS RUNDOWN is a news-based daily morning podcast delivering a deep dive into the major and controversial stories of the day.',
#   7),
#  ('You know what?', 7),
#  ('China’s National Health Commission is expected to release numbers for all of China’s provinces later.',
#   7),
#  ('PIRRO: Okay.', 7),
#  ('Probably not.', 7),
#  ('Listen.', 7),
#  ('HANNITY: Yes.', 7),
#  ('Fox News medical correspondent Dr. Marc Siegel reports from Omaha, Nebraska.',
#   7),
#  ('CDC WARNS ON CORONAVIRUS IN US: SHOULD YOU START TO WORRY?', 7),
#  ('Really?', 7),
#  ('"Coronavirus, they\'re politicizing it.', 7),
#  ("They go, 'oh not good, not good.'", 7),
#  ('"One of my people came up to me and said, \'Mr.', 7),
#  ("They tried the impeachment hoax,' that was on a perfect conversation, 'they tried anything, they tried it over and over and they've been doing it since you got in.",
#   7),
#  ('The NCAA later canceled the men’s and women’s basketball tournaments over the coronavirus pandemic that has swept the globe and put all of American sports on lockdown.',
#   7),
#  ('Fox News medical contributor Dr. Marc Siegel weighs in.', 7),
#  ('(CHEERING AND APPLAUSE)  TRUMP: Thank you.', 7),
#  ('Hank Greenberg; President of the New York Bar Association weighs in.', 7),
#  ("It's true.", 7),
#  ('7.', 7),
#  ('Nothing is shut down, life & the economy go on.', 7),
#  ('At this moment there are 546 confirmed cases of CoronaVirus, with 22 deaths.',
#   7),
#  ('"The virus will not have a chance against us.', 7),
#  ('No nation is more prepared, or more resilient," Trump said.', 7),
#  ("WHAT IS THE 'CHRISTIAN RESPONSE' TO THE CORONAVIRUS?", 7),
#  ('Thousands of people have asked us questions about the outbreak.', 7),
#  ('The outbreak is believed to have originated at an animal and seafood market in the city of Wuhan, China.',
#   7),
#  ('WHAT PRECAUTIONS CAN I TAKE?', 7),
#  ('LIMITED TIME OFFER, GET YOUR FIRST MONTH OF FOX NATION FOR $0.99 Fox Nation programs are viewable on-demand and from your mobile device app, but only available only for Fox Nation subscribers.',
#   7),
#  ('QUESTIONS ABOUT CORONAVIRUS?', 7),
#  ('HOW DID THE CORONAVIRUS OUTBREAK START?', 7),
#  ('The president also announced a temporary halt on air travel to the United States from Europe, now including flights from the United Kingdom, but excluding those carrying cargo.',
#   7),
#  ('This blog is now closed.', 7),
#  ('(Click here to view.)', 7),
#  ("'Fox News @ Night' anchor Shannon Bream delivers a 2020 update in 60 seconds on the biggest political stories.",
#   7),
#  ('The annual service, organized by the Royal Commonwealth Society, is the largest annual inter-faith gathering in the United Kingdom.',
#   7),
#  ('Here is how the Queen is showing her determination to support the people of the United Kingdom during these uncertain times.',
#   7),
#  ('SENS.', 7),
#  ("Here's what you need to know.", 7),
#  ('WORKING FROM HOME DURING CORONAVIRUS OUTBREAK?', 7),
#  ("We'll be back tomorrow.", 7),
#  ('Fox News’ Joseph A. Wulfsohn contributed to this report.', 7),
#  ('They are currently at their home, Burnham on the Balmoral Estate, in Scotland "self-isolating," the statement confirmed.',
#   7),
#  ('Stay home.', 7),
#  ('ET on all FOX platforms and iHeartMedia radio stations nationwide.', 7),
#  ('I think we should run snippets.', 7),
#  ('**Want FOX News Halftime Report in your inbox every day?', 7),
#  ('Brianna McClelland contributed to this report.', 7),
#  ('Want FOX News Halftime Report in your inbox every day?', 7),
#  ('CORONAVIRUS OUTBREAK SPARKS FACE MASK DEBATE: SHOULD YOU WEAR THEM?', 7),
#  ('The United States also voluntarily gives between approximately $100 million and $400 million more per year to the WHO for specific projects -- contributions that totaled over $400 million in 2017, the most recent year for which figures are available.',
#   7),
#  ('We will be with our friends again.', 7),
#  ('We will be with our families again.', 7),
#  ('John, thanks.', 6),
#  ('Back to you.', 6),
#  ('That\'s tonight\'s live look "OUTSIDE THE BELTWAY" from SPECIAL REPORT.',
#   6),
#  ('She joins us tonight.', 6),
#  ('CARLSON: Right.', 6),
#  ('Content and Programming Copyright 2020 Fox News Network, LLC.', 6),
#  ('WILLIAMS: Yes.', 6),
#  ('Here are the latest figures.', 6),
#  ('Russia has signed an order to close the border between them and China.', 6),
#  ('Whatever.', 6),
#  ('The Allied Pilots Association (APA), which represents 15,000 pilots for American Airlines filed a lawsuit to halt service with the airline, citing “serious, and in many ways still unknown, health threats posed by the coronavirus."',
#   6),
#  ('"I am directing all APA pilots to cease flight operations between the United States and China," said APA president Eric Ferguson.',
#   6),
#  ('"Until further notice, if you are scheduled, assigned, or reassigned a pairing into China, decline the assignment by calling your Chief Pilot or IOC Duty Pilot.',
#   6),
#  ('Inform them you are declining in accordance with the CDC and WHO declarations."',
#   6),
#  ('Lion Air canceled 50 flights to China into February.', 6),
#  ('Good evening, John.', 6),
#  ("That's the focus of tonight's Angle.", 6),
#  ('You know what I mean?', 6),
#  ('We know that.', 6),
#  ('Overall, at least 25 countries have reported cases of coronavirus.', 6),
#  ('WATTERS: Right.', 6),
#  ('First, "BEYOND OUR BORDERS" tonight.', 6),
#  ('Good to see you tonight.', 6),
#  ('Peter, thanks.', 6),
#  ('SCOTT: Yes.', 6),
#  ('CLICK HERE FOR THE FOX NEWS APP The Associated Press contributed to this report.',
#   6),
#  ('Listen to this.', 6),
#  ('Of course.', 6),
#  ('The Associated Press contributed to this reportFox News Flash top headlines are here.',
#   6),
#  ("I'm a Democratic candidate for the United States Senate.", 6),
#  ('he wrote.', 6),
#  ('Here are some ways of coping with the increase in social isolation in response to the outbreak.',
#   6),
#  ('CALIFORNIA GOV.', 6),
#  ('You can listen to or watch The Kim Komando Show on your phone, tablet, television or computer.',
#   6),
#  ("Kim takes calls and dispenses advice on today's digital lifestyle, from smartphones and tablets to online privacy and data hacks.",
#   6),
#  ('Connecticut Gov.', 6),
#  ('Right, Joe?', 6),
#  ('9.', 6),
#  ('KURTZ: Right.', 6),
#  ('Chan School of Public Health.', 6),
#  ('What to do next?', 6),
#  ('Rita and I are down here in Australia.', 6),
#  ('Slight fevers too.', 6),
#  ('John Bel Edwards.', 6),
#  ('CLICK HERE TO GET THE FOX NEWS APPFox News Flash top entertainment and celebrity headlines are here.',
#   6),
#  ('Find out what insiders are saying about how the coronavirus is disrupting the sports industry.',
#   6),
#  ('Georgia Gov.', 6),
#  ('Sens.', 6),
#  ("Fox News' Chad Pergram contributed to this report.", 6),
#  ('Massachusetts Gov.', 6),
#  ('Kentucky Gov.', 6),
#  ('Stay safe.', 6),
#  ('Good News: One week after testing Positive, in self-isolation, the symptoms are much the same.',
#   6),
#  ('No fever but the blahs," Hanks revealed.', 6),
#  ('We are all in this together.', 6),
#  ("That can't happen.", 6),
#  ('CAN YOU CATCH CORONAVIRUS FROM SURFACES?', 6),
#  ('Cuomo are just two officials considering how to address this issue.', 6),
#  ('“There’s a social contract here.', 6),
#  ('People, I think, recognize the need to do more.', 6),
#  ("'Tucker Carlson Tonight' will have more on the story on Friday.", 6),
#  ('"...', 6),
#  ('They are really frightened.', 6),
#  ('And when these things don’t come true, you just exacerbate their concern.',
#   6),
#  ('The total includes cases from all 50 states, the District of Columbia and other U.S. territories, as well as all repatriated cases.',
#   6),
#  ("Gretchen Whitmer joins John Roberts on 'Fox News Sunday.'", 6),
#  ('LIMITED TIME OFFER, GET YOUR FIRST MONTH OF FOX NATION FOR 99 CENTS Fox Nation programs are viewable on-demand and from your mobile device app, but only for Fox Nation subscribers.',
#   6),
#  ('Democrats said the package specifically would help replace the salaries of furloughed workers for four months, rather than the three months first proposed.',
#   6),
#  ('DO YOU QUALIFY FOR A STIMULUS CHECK IN SENATE’S CORONAVIRUS RESPONSE BILL?',
#   6),
#  ('He has been displaying mild symptoms but otherwise remains in good health and has been working from home throughout the last few days as usual," the Clarence House said to Fox News in a statement Wednesday morning.',
#   6),
#  ('WHERE WAS PRINCE CHARLES BEFORE TESTING POSITIVE FOR CORONAVIRUS?', 6),
#  ('Are you a health care worker fighting Covid-19?', 6),
#  ("Don't be threatening.", 6),
#  ('The Rev.', 6),
#  ('It averages between 27,000 and 70,000 per year.', 6),
#  ('We look forward to reconnecting with you soon.', 6),
#  ('WHAT PRECAUTIONS SHOULD I TAKE?', 6),
#  ('- Email us at HALFTIMEREPORT@FOXNEWS.COM with your tips, comments or questions.SCOREBOARDESTIMATED DELEGATES FOR DEMOCRATIC NOMINATIONBiden: 1,217Sanders: 914[Ed.',
#   6),
#  ('All market data delayed 20 minutes.Dr.', 6),
#  ('CLICK HERE TO READ MORE FROM TUCKER CARLSON Get the recap of top opinion commentary and original content throughout the week.',
#   6),
#  ('Follow below on the Fox News live blog.', 6),
#  ('Mobile users click here.', 6),
#  ('Tweet her @EmilyDeCiccio.', 6),
#  ('I have lots of friends who were staring into the future thinking, "How are we going to do this?"',
#   6),
#  ('Sailors do not need to die.', 6),
#  ('"People should not be forced to put their lives on the line to vote, which is why 15 states are now following the advice of public health experts and delaying their elections.',
#   6),
#  ('We urge Wisconsin to join them," the senator said in a statement on Wednesday.',
#   6),
#  ('Two of the three sources called the numbers flat-out fake.', 6),
#  ('The true numbers are certainly much higher, because of limited testing, different ways nations count the dead and deliberate under-reporting by some governments.',
#   6),
#  ('"But now, as then, we know deep down that it is the right thing to do.', 6),
#  ('While we have faced challenges before, this one is different.', 6),
#  ('"We should take comfort that while we may have more still to endure, better days will return.',
#   6),
#  ('We will meet again.', 6),
#  ('But for now, I send my thanks and warmest good wishes to you all."', 6),
#  ('Good evening, Mike.', 5),
#  ('But just how well do surgical masks really work?', 5),
#  ('JOHN ROBERTS, FOX NEWS CHIEF WHITE HOUSE CORRESPONDENT: Bret, good evening to you.',
#   5),
#  ("I don't care.", 5),
#  ("That's a good thing.", 5),
#  ("That's fine.", 5),
#  ('CARLSON: Thank you.', 5),
#  ('How are you?', 5),
#  ('Thank you for that.', 5),
#  ('Janette Nesheiwat explains the risks and symptoms.', 5),
#  ('Amazing.', 5),
#  ("We don't know.", 5),
#  ("We don't know that.", 5),
#  ('British Airways suspended all flights to and from mainland China.', 5),
#  ("We'll see you in your inbox first thing Friday morning.", 5),
#  ('Good luck.', 5),
#  ('GUTFELD: Yes, exactly.', 5),
#  ('GRAHAM: Yes.', 5),
#  ('This is ridiculous.', 5),
#  ('HOW ARE US HOSPITALS PREPARING FOR CORONAVIRUS?', 5),
#  ('Foreign nationals who recently went to China would be denied entry in the U.S., except for the immediate family of American citizens and permanent residents.',
#   5),
#  ('The WHO said the number of cases will keep growing as tests are pending on thousands of suspected cases.',
#   5),
#  ('Where is the virus?', 5),
#  ('Roughly 99 percent of new cases have appeared in China with the vast majority of the cases in Hubei province and its provincial capital, Wuhan -- the epicenter of the virus.',
#   5),
#  ('The flu has estimated to have killed roughly 10,000 to 25,000 people with nearly 19 to 26 million infected in the U.S. between October 1, 2019, and January 25, 2020, according to the CDC.',
#   5),
#  ("Coronavirus has impacted a far lesser number, although it's not yet clear how many have been infected or how widespread it is.",
#   5),
#  ('There have also been reports it can be spread without symptoms showing up.',
#   5),
#  ('In respiratory illnesses, people with the most symptoms are the most contagious, the agency said.',
#   5),
#  ('Children and those over 65 are the most likely to get sick from the flu, the CDC added.',
#   5),
#  ('People over six months out are advised by the agency to get it during annual vaccination, with certain rare exceptions, such as severe allergies to the shot.',
#   5),
#  ('What are the current travel restrictions?', 5),
#  ('The Department of State has requested that all non-essential U.S. government personnel defer travel to China in light of the novel coronavirus," The advisory said.',
#   5),
#  ('Vietnam stopped all flights to and from China.', 5),
#  ('Japan, Singapore, Indonesia, New Zealand, and Australia all have similar policies to the U.S. on restricting non-citizens.',
#   5),
#  ('Mongolia and Singapore have shut their borders.', 5),
#  ('Italy suspended all flights to China.', 5),
#  ('CLICK HERE TO SIGN UP FOR THE FOX HEALTH NEWSLETTER  Kenya Airways suspends all flights to China.',
#   5),
#  ('Nothing.', 5),
#  ('Hey, Bill.', 5),
#  ('What do you make of that?', 5),
#  ("We'll see.", 5),
#  ('Sorry.', 5),
#  ('Just some of the other stories "BEYOND OUR BORDERS" tonight.', 5),
#  ('Six other cases have been confirmed in California, as well as one in Wisconsin, one in Arizona, one in Massachusetts and two in Illinois.',
#   5),
#  ('It does.', 5),
#  ("We'll explain.", 5),
#  ('PERINO: Yes.', 5),
#  ('BARTIROMO: Right.', 5),
#  ('PIRRO: Right.', 5),
#  ('MCCARTHY: Yes.', 5),
#  ('It is.', 5),
#  ('Not at all.', 5),
#  ('These numbers may differ from those reported by national health authorities, who report updated totals at different times than the WHO.',
#   5),
#  ('Here we go again.', 5),
#  ('You know?', 5),
#  ('“Mr.', 5),
#  ('(END VIDEO CLIP) HANNITY: All right.', 5),
#  ('I think teaching people to read and write is a good thing.', 5),
#  ('FAUCI: Right.', 5),
#  ('This is a developing story.', 5),
#  ('Janette Nesheiwat on precautions to take while flying and areas to avoid traveling to.',
#   5),
#  ('This story originally appeared in the New York Post.', 5),
#  ('CLICK HERE TO READ MORE FROM TUCKER CARLSONFox News Flash top headlines are here.',
#   5),
#  ('That was not a good friendship.', 5),
#  ('They switched on me.', 5),
#  ('(AP Photo/Mahesh Kumar A.)', 5),
#  ("Call Kim's national radio show and tap or click here to find it on your local radio station.",
#   5),
#  ("Or tap or click here for Kim's free podcasts.", 5),
#  ('8.', 5),
#  ('WOODSON: Yes.', 5),
#  ('WOODSON: Right.', 5),
#  ("LEVIN: We'll be right back.", 5),
#  ('Think about that!"', 5),
#  ('Andrew Cuomo announced that prisoner-made hand sanitizer with be available to New Yorkers free of charge.',
#   5),
#  ('(AP Photo/J.', 5),
#  ("Fox News' Barnini Chakraborty contributed to this report.", 5),
#  ('We get it.', 5),
#  ('The Medical Officials have protocols that must be followed.', 5),
#  ('We Hanks’ will be tested, observed, and isolated for as long as public health and safety requires.',
#   5),
#  ('According to the CDC, there are 70 cases from repatriated citizens.', 5),
#  ('Let him go.', 5),
#  ('"We have chosen to make a transition this year in starting to carve out a progressive new role within this institution," the couple shared on Instagram.',
#   5),
#  ('It is with your encouragement, particularly over the last few years, that we feel prepared to make this adjustment.',
#   5),
#  ('Arkansas Gov.', 5),
#  ('What are the names of the hospitals?', 5),
#  ('Not much more to it than a one-day-at-a-time approach, no?', 5),
#  ('We felt a bit tired, like we had colds, and some body aches.', 5),
#  ('Rita had some chills that came and went.', 5),
#  ('Neither came in contact with the ill individual, according to the White House.',
#   5),
#  ('We send our best wishes to all individuals and communities that have been impacted by coronavirus."',
#   5),
#  ('“Hello, folks.', 5),
#  ('For most people, the virus causes only mild or moderate symptoms, such as fever and cough.',
#   5),
#  ('FLYING DURING THE CORONAVIRUS OUTBREAK: SHOULD I CANCEL MY FLIGHT?', 5),
#  ('Here are some precautions to take.', 5),
#  ('This story has been updated with additional developments.', 5),
#  ('"Gov.', 5),
#  ('“With several weeks of focused action, we can turn the corner and turn it quickly,” Trump said.',
#   5),
#  ('For some, especially older adults and people with existing health problems, it can cause more severe illness, including pneumonia, and death.',
#   5),
#  ('CLICK HERE TO GET THE FOX NEWS APP For most people, the new coronavirus has caused only mild or moderate symptoms, such as fever and cough.',
#   5),
#  ('Here’s what you need to know about your favorite restaurants.', 5),
#  ('Nobody, even the medical community, can predict it with certainty.', 5),
#  ("Marc Siegel answers questions from 'Fox &amp; Friends' viewers.", 5),
#  ('“Americans need cash now, the president wants to get cash now.', 5),
#  ('CLICK HERE TO GET THE FOX NEWS APPDr.', 5),
#  ('These include receiving the Prime Minister, the Commanding Officer of HMS QUEEN ELIZABETH and the Bishop of Hereford.',
#   5),
#  ('"Folding the laundry and doing the dishes leads to a nap on the couch."',
#   5),
#  ('I want to be accurate."', 5),
#  ('"I think they probably would agree with it, 100 percent.', 5),
#  ("It comes from China, that's why.", 5),
#  ('The legislation provides 14 days of paid sick days to workers affected by the coronavirus, ensures free testing to everyone, including the uninsured, and expands food aid and boosts unemployment dollars to states.',
#   5),
#  ('The House and Senate already passed a bipartisan $8.3 billion package to prop up the health care system to prepare for the influx of sick Americans.',
#   5),
#  ('Trace Gallagher speaks with small business owner in Spain, Dean Kamuchey.',
#   5),
#  ('The drive-in theater, long a dwindling nostalgia act in a multiplex world, is experiencing a momentary return to prominence.',
#   5),
#  ('With nearly all of the nation’s movie theaters shuttered due to the pandemic, some drive-in owners think they’re in a unique position to give moviegoers a chance to do something out of the house but stay within prudent distance from one another.',
#   5),
#  ('For all those willing to lend a helping hand, here are some places volunteers can go to help.',
#   5),
#  ('"Our temperature is not the same during the day.', 5),
#  ('If you take it at eight o\'clock in the morning, it may be normal," Schaffner explained.',
#   5),
#  ('"It\'s not a tickle in your throat.', 5),
#  ("You're not just clearing your throat.", 5),
#  ('"If there\'s any shortness of breath immediately call your health care provider, a local urgent care or the emergency department," said American Medical Association president Dr. Patrice Harris.',
#   5),
#  ('"If the shortness of breath is severe enough, you should call 911," Harris added.',
#   5),
#  ('Get medical attention immediately, the CDC says.', 5),
#  ('So what should you do?', 5),
#  ("It's unclear whether pregnant women have a greater chance of getting severely ill from coronavirus, but the CDC has said that women experience changes in their bodies during pregnancy that may increase their risk of some infections.",
#   5),
#  ('In general, Covid-19 infections are riskier if you have underlying health conditions such as diabetes, chronic lung disease or asthma, heart failure or heart disease, sickle cell anemia, cancer (or are undergoing chemotherapy), kidney disease with dialysis, a body mass index (BMI) over 40 (extremely obese) or an autoimmune disorder.',
#   5),
#  ('"By preying upon Americans’ fear amid the coronavirus outbreak, Biden isn’t just playing cheap politics.',
#   5),
#  ('He’s making the crisis worse.', 5),
#  ('"Biden\'s Monday morning quarterbacking is an effort to sow anger and division among Americans."',
#   5),
#  ('Pharmacies, supermarkets, groceries and bakeries will remain open.', 5),
#  ('Maxim Lott is Executive Producer of Stossel TV and creator of ElectionBettingOdds.com.',
#   5),
#  ("Nicole Saphier answers viewers' coronavirus questions.", 5),
#  ('Furloughed workers would get whatever amount a state usually provides for unemployment, plus a $600 per week add-on, with gig workers like Uber drivers covered for the first time.',
#   5),
#  ('And this is "Coronavirus: Fact vs.', 5),
#  ('The holiday this year lands on April 12.', 5),
#  ('One of the last issues to close concerned $500 billion for guaranteed, subsidized loans to larger industries, including a fight over how generous to be with the airlines, given that Democrats wanted them to abide by new carbon emissions restrictions.',
#   5),
#  ('He also said he worries the U.S. will see "suicides by the thousands" if coronavirus devastates the economy.',
#   5),
#  ('Instead, they are hoping to build immunity to the virus as a natural vaccine.',
#   5),
#  ('Here’s the latest on a Chinese biotechnology company that sold millions of fault testing kits to countries in desperate need of them.',
#   5),
#  ('WORLD HEALTH ORGANIZATION UNDER THE MICROSCOPE: WHAT WENT WRONG WITH CORONAVIRUS?',
#   5),
#  ('More than 50,000 people have asked us questions about the outbreak.', 5),
#  ('Pastor Tony Spell has defied a shelter-in-place order by Louisiana Gov.',
#   5),
#  ('John Bel Edwards, due to the new coronavirus pandemic, and continues to hold church services with hundreds of congregants.',
#   5),
#  (']WANT MORE HALFTIME REPORT?', 5),
#  ('You can join Chris and Brianna every day on Fox Nation.', 5),
#  ('It’ll be the same behind-the-scenes look at your favorite political note, only from their remote locations during this unprecedented time.',
#   5),
#  ('Without any measures in place to mitigate the contagion&aposs spread, those projections jump to between 1.5 and 2.2 million deaths from COVID-19.',
#   5),
#  ('Fox News&apos Barnini Chakraborty contributed to this report.', 5),
#  ('CLICK HERE TO READ MORE FROM GREG GUTFELD Get the recap of top opinion commentary and original content throughout the week.',
#   5),
#  ('That means the United States contributed over $500 million in total to the WHO that year, which is just under one-quarter of the organization&aposs yearly budget.',
#   5),
#  ('CLICK HERE TO GET THE FOX NEWS APP Get the recap of top opinion commentary and original content throughout the week.',
#   5),
#  ('He was 85.', 5),
#  ('Fox News&apos Andrew O&aposReilly contributed to this report.', 5),
#  ('"With over $2 trillion in emergency relief, we need to ensure those dollars are spent carefully and effectively," Pelosi said of the massive stimulus bill Congress already passed to address the coronavirus pandemic.',
#   5),
#  ('Fox News&apos Bill Mears contributed to this report.', 5),
#  ('What do you have to lose?"', 5),
#  ('It reminds me of the very first broadcast I made in 1940 helped by my sister.',
#   5),
#  ('This time we join with all nations across the globe in a common endeavor using the great advances of science and our instinctive compassion to heal."',
#   5),
#  ('"We will succeed, and that success will belong to every one of us," she concluded.',
#   5),
#  ('We pick our carrier commanding officers with great care.', 5),
#  ("There aren't many preemptive steps that can be taken to avoid infection, other than practicing basic sanitary measures on a regular basis.",
#   4),
#  ('Passengers wear masks to prevent an outbreak of a new coronavirus in a subway station, in Hong Kong, Wednesday, Jan. 22, 2020.',
#   4),
#  ('Never miss an episode of THE FIVE.', 4),
#  ('Jonathan, thank you.', 4),
#  ('CORONAVIRUS: WHO IS MOST AT-RISK?', 4),
#  ('Get her out tomorrow.', 4),
#  ("First, here's what some of our Fox affiliates around the country are covering tonight.",
#   4),
#  ("That's why.", 4),
#  ("You're absolutely right.", 4),
#  ('Congresswoman, thanks so much for coming on.', 4),
#  ("Here's the problem.", 4),
#  ('We will continue to monitor the situation as it develops and will adjust our schedule as needed,” United said a statement to Fox News.',
#   4),
#  ('officials ordered workers at the U.S. consulate in Wuhan to return to the United States; Rich Edson reports from the State Department.',
#   4),
#  ('What do you think of that?', 4),
#  ('All materials herein are protected by United States copyright law and may not be reproduced, distributed, transmitted, displayed, published or broadcast without the prior written permission of Fox News Network, LLC.',
#   4),
#  ('The number of cases confirmed in mainland China has now surpassed those that were sickened during a SARS outbreak in 2002-2003.',
#   4),
#  ('Why is that?', 4),
#  ('Come on.', 4),
#  ('They hate you.', 4),
#  ('PAVLICH: Yeah.', 4),
#  ('Take a listen.', 4),
#  ('Officials at the CDC have advised travelers to avoid all nonessential travel to the country.',
#   4),
#  ('American Airlines suspended L.A. flights to and from Shanghai and Beijing.',
#   4),
#  ('UNIDENTIFIED MALE: Mr. Chief Justice.', 4),
#  ("Fox News' David Aaro contributed to this report.", 4),
#  ('No, not at all.', 4),
#  ('CARLSON: Exactly.', 4),
#  ('"Those currently in China should consider departing using commercial means.',
#   4),
#  ('The World Health Organization (WHO) declared the outbreak a global emergency as it spreads to countries outside of China and the number of infected patients continues to grow.',
#   4),
#  ("STATE DEPARTMENT, CITING CORONAVIRUS OUTBREAK, RAISES CHINA TRAVEL ADVISORY: 'DO NOT TRAVEL' U.S. Centers for Disease Control and Prevention (CDC) have advised travelers to avoid all nonessential travel to the country.",
#   4),
#  ('The U.S. expanded the screening of travelers arriving from Wuhan from five to 20 airports.',
#   4),
#  ('Thanks.', 4),
#  ('Nobody knows.', 4),
#  ('You know why?', 4),
#  ('GRAHAM: Thank you.', 4),
#  ('BARTIROMO: Wow.', 4),
#  ('Countries around the globe have increased travel restrictions to the infected mainland China and Hubei province — with the U.S. State Department increasing its advisory to level 4: "Do Not Travel."',
#   4),
#  ('How did it start?', 4),
#  ('A study by the Wuhan Institute of Virology said that genome sequences from seven patients tested were identical to the bat coronavirus.',
#   4),
#  ('How does it transmit?', 4),
#  ("It's believed the normal coronavirus can be transmitted most commonly through respiratory droplets in the air, as well as close contact with an infected person or touching areas contaminated with the virus before washing.",
#   4),
#  ('They recently discovered "virus genetic material" in feces samples and rectal swabs from some patients, Chinese state media reported.',
#   4),
#  ("CORONAVIRUS: PRESIDENT TRUMP SAID US AUTHORITIES 'SHUT IT DOWN.'", 4),
#  ('“Dr.', 4),
#  ('More than 24,000 people have been infected worldwide.', 4),
#  ('We really appreciate it.', 4),
#  ('BAIER: Jonathan, thank you.', 4),
#  ("It's incredible.", 4),
#  ('Thank you for being with us.', 4),
#  ("That's the problem.", 4),
#  ('GIULIANI: Yes.', 4),
#  ('We choose truth over facts.', 4),
#  ("What's going on?", 4),
#  ('PIRRO: All right.', 4),
#  ("Don't go away.", 4),
#  ('WILL THE CORONAVIRUS DIE OUT AS THE WEATHER WARMS?', 4),
#  ('MACCALLUM: Absolutely.', 4),
#  ('Thanks so much for that.', 4),
#  ('Are you kidding me?', 4),
#  ('China is struggling to return to work after businesses were shut and schools suspended for weeks.',
#   4),
#  ('Millions are now working from home, with Chinese President Xi Jinping warning on Monday that the country needed to stabilize its economy and avoid mass layoffs.',
#   4),
#  ('Why would they do that?', 4),
#  ("Here's why.", 4),
#  ('Trends can change as new populations are affected.', 4),
#  ('We see relatively few cases among children.', 4),
#  ('Residents in each city receive daily necessities from neighborhood and community committees as they are not permitted to leave their homes.',
#   4),
#  ('Chinese authorities on Monday reported a slight upturn in new virus cases and hundred more deaths for a total of thousands since the outbreak began two months ago.',
#   4),
#  ('Yeah.', 4),
#  ('A spokesperson for Princess Cruises was not immediately available to offer further comment.',
#   4),
#  ('What does that mean?', 4),
#  ('CAVUTO: Wow.', 4),
#  ('Thanks for being here.', 4),
#  ('They did.', 4),
#  ('"Because of all we\'ve done, the risk to the American people remains very low," Trump said.',
#   4),
#  ('Well said.', 4),
#  ('CARLSON:  Exactly.', 4),
#  ('Good evening, Jackie.', 4),
#  ('Look me over.', 4),
#  ('Congress in recent years took a similar approach with the opioid epidemic, pumping out federal dollars for treatment and prevention.',
#   4),
#  ('Senate Democratic Leader Chuck Schumer of New York unveiled an $8.5 billion coronavirus proposal.',
#   4),
#  ('"We\'re ready to adapt, and we\'re ready to do whatever we have to."', 4),
#  ('IS CORONAVIRUS A PANDEMIC OR AN EPIDEMIC?', 4),
#  ('DE BLASIO: Uh-huh.', 4),
#  ('Do you agree with that?', 4),
#  ("Fox News' Chad Pergram and The Associated Press contributed to this report.",
#   4),
#  ('They can\'t even count their votes in Iowa -- not they can\'t, they can\'t count their votes."',
#   4),
#  ('It\'s all turning, they lost, it\'s all turning -- think of it, think of it, and this is their new hoax.\'"',
#   4),
#  ('Fox News’ David Spunt reports from the White House.', 4),
#  ('Thanks for your time.', 4),
#  ('Sec.', 4),
#  ('KURTZ:  Right.', 4),
#  ('KURTZ:  All right.', 4),
#  ('People are worried.', 4),
#  ('Copyright 2020 ASC Services II Media, LLC.', 4),
#  ('All materials herein are protected by United States copyright law and may not be reproduced, distributed, transmitted, displayed, published or broadcast without the prior written permission of ASC Services II Media, LLC.',
#   4),
#  ('Despite that, however, the White House is expected to back the deal.', 4),
#  ('HANNITY:  All right.', 4),
#  ('No other details were provided.', 4),
#  ('FAUCI: Yes.', 4),
#  ("We've interviewed experts and found the best options to help you cope during this uncertain time.",
#   4),
#  ('Find all of our coronavirus-related coverage here, and let us know your thoughts here.',
#   4),
#  ('Fox News recently celebrated its 18th consecutive year as the most-watched cable news network, dating back to January 2002.',
#   4),
#  ("Learn about all the latest technology on The Kim Komando Show, the nation's largest weekend radio talk show.",
#   4),
#  ('For her daily tips, free newsletters and more, visit her website at Komando.com.',
#   4),
#  ("That's right.", 4),
#  ("I ain't playing.", 4),
#  ('TRUMP: Thank you.', 4),
#  ("Support me, I'm running for the United States -- there's something going on there.",
#   4),
#  ('(BEGIN VIDEO CLIP) GOV.', 4),
#  ("It's an incredible way of putting it.", 4),
#  ("Let's put it up on the screen.", 4),
#  ('GUTFELD: True.', 4),
#  ('Goodbye.', 4),
#  ('HEGSETH: Okay.', 4),
#  ("'Dr.", 4),
#  ('10.', 4),
#  ('Have a question about coronavirus?', 4),
#  ('Ask us here.', 4),
#  ('KURTZ: All right.', 4),
#  ("White House officials said when Gaetz learned he was in proximity to the man with coronavirus at CPAC, he sat by himself in a section of the president's plane.",
#   4),
#  ('In mainland China, where the virus first exploded, more than 80,000 people have been diagnosed and more than 58,000 have so far recovered.',
#   4),
#  ('HOW IS GERMANY CONTROLLING THE CORONAVIRUS OUTBREAK?', 4),
#  ('"It may well be that Iran is now the epicenter of the outbreak.', 4),
#  ('The government has and continues to misreport the number of cases and deaths.',
#   4),
#  ('You bet.', 4),
#  ('China.', 4),
#  ('Are we ready for that?', 4),
#  ('CLICK HERE TO GET THE FOX NEWS APP For most people, the new coronavirus causes only mild or moderate symptoms, such as fever and cough.',
#   4),
#  ("Fox News' Gregg Re contributed to this report.", 4),
#  ("IRAN'S CORONAVIRUS COVER-UP: IS IT NOW THE EPICENTER OF THE VIRUS?", 4),
#  ('We need it.', 4),
#  ('"This geographic balance will enable us to raise our son with an appreciation for the royal tradition into which he was born, while also providing our family with the space to focus on the next chapter, including the launch of our new charitable entity."',
#   4),
#  ('“The NBA is suspending game play following the conclusion of tonight’s schedule of games until further notice,” the statement read.',
#   4),
#  ('We’ll keep the world posted and updated.', 4),
#  ("Hanks plays Presley's manager Colonel Tom Parker.", 4),
#  ('Similarly, the release date for "No Time to Die," the upcoming James Bond flick, was pushed back to November.',
#   4),
#  ('His address came hours after the World Health Organization declared the COVID-19 a global pandemic and the number of confirmed cases in the U.S. climbed to more than 1,200.',
#   4),
#  ('Fox News’ David Aaro contributed to this report.', 4),
#  ('This story has been updated with additional developments Wednesday.', 4),
#  ('Janette Nesheiwat on what this means for the American people.', 4),
#  ('Oregon Gov.', 4),
#  ('At the time, I had no idea I was even infected.', 4),
#  ('"Do I think we should be?', 4),
#  ('We are taking it one-day-at-a-time.', 4),
#  ('Fox News contributor Dr. Nicole Saphier weighs in.', 4),
#  ("Fox News' Ronn Blitzer contributed to this report.", 4),
#  ("Reactions from 'The Five'.", 4),
#  ('CORONAVIRUS AT THE AIRPORT: HOW CAN I AVOID GERMS?', 4),
#  ("Fox News' Hollie McKay contributed to this report.", 4),
#  ('John Bel Edwards said.', 4),
#  ('VISITING THE DOCTOR DURING CORONAVIRUS: SHOULD YOU RESCHEDULE YOUR APPOINTMENT?',
#   4),
#  ('Sure.', 4),
#  ('IS CORONAVIRUS A THREAT TO CHILDREN?', 4),
#  ('To read, hear, and watch more of Newt Gingrich’s commentary, visit Gingrich360.com.',
#   4),
#  ("Spain's government announced Saturday that it is placing tight restrictions on movements and closing restaurants and other establishments in the nation of 46 million people as part of a two-week state of emergency to fight the sharp rise in coronavirus infections.",
#   4),
#  ('Nearly 74,000 people worldwide have recovered after being infected.', 4),
#  ('Amen.', 4),
#  ('Many elderly folks experience homelessness.', 4),
#  ('“I’m thinking about some of the elderly people sitting behind the desks, registering people and doing all that stuff.',
#   4),
#  ('Does that make sense?', 4),
#  ('The announcement came as major sporting and other events were called off or postponed, businesses across the country instituted telework policies, government buildings and schools shuttered and other disruptions rocked the nation, amid efforts to curb the transmission of the virus.',
#   4),
#  ('“Nobody knows how long the hiatus may be.', 4),
#  ('The coronavirus, for most, causes only mild or moderate symptoms, such as fever and cough.',
#   4),
#  ("Fox News' Tyler McCarthy contributed to this report.", 4),
#  ('Stay inside.', 4),
#  ('Wash your hands.', 4),
#  ('The royal family\'s statement also made it clear it is making steadfast decisions based on advice from the family\'s "medical household" as well as government officials.',
#   4),
#  ('This means events with "large numbers of people" that were due to be attended by the queen and other royal family members will be canceled or postponed "in the coming months."',
#   4),
#  ("The family's annual Maundy service at St. George's Chapel on April 9 has already been canceled, and along with it, three garden parties scheduled to be hosted by the queen in May will also no longer be held, the statement confirmed.",
#   4),
# ...
#   4),
#  ('I haven’t thought about any more debates.', 4),
#  ('I think we’ve had enough debates.', 4),
#  ('She was so patient with us.', 4),
#  ('She will let us out to play again.', 4),
#  ('How will we use this time?', 4),
#  ('On Tuesday, Gov.', 4),
#  ("Fox News' Nate Day contributed to this report.", 4),
#  ('Drs.', 4),
#  ('More than a dozen other states allow mail-in-voting as an option.', 4),
#  ('The Washington Post, which is also owned by Bezos, reported that Amazon workers at 10 warehouses around the country have tested positive for COVID-19.',
#   4),
#  ('Navy Capt.', 4),
#  ('For the most up-to-date US numbers compiled by CNN, please check this map which automatically refreshes every 10 minutes.',
#   4),
#  ("Here's what you need to know to Get Up to Speed and On with Your Day.", 4),
#  ('He was 98.', 4),
#  ('Those traveling on flights from the tristate area -- New York, New Jersey or Connecticut – as well as Louisiana, will be met by National Guard troops and public health officials at major Florida airports.',
#   4),
#  ('Be nice."', 4),
#  ("TRANSCRIPT Click here to access the printable version of today's CNN 10 transcript.",
#   4),
#  ('CNN 10 serves a growing audience interested in compact on-demand news broadcasts ideal for explanation seekers on the go or in the classroom.',
#   4),
#  ("The show's priority is to identify stories of international significance and then clearly describe why they're making news, who is affected, and how the events fit into a complex, international society.",
#   4),
#  ('CRUISING DURING THE CORONAVIRUS OUTBREAK: SHOULD I CANCEL MY CRUISE?', 4),
#  ("Larry Hogan joins 'America's Newsroom' with an update.", 4),
#  ('"He was also found to have had close contact with a diagnosed associate with a confirmed case of COVID-19 and was asked to remain home with pay for 14 days, which is a measure we’re taking at sites around the world.',
#   4),
#  ('Despite that instruction to stay home with pay, he came onsite today, March 30, further putting the teams at risk.',
#   4),
#  ('This is unacceptable and we have terminated his employment as a result of these multiple safety issues."',
#   4),
#  ('They also receive double time for overtime and the company recently instituted daily temperature screenings at the fulfillment center, which houses some 2,500 employees.',
#   4),
#  ('Democratic presidential candidate Sanders has been a vocal critic of Amazon.',
#   4),
#  ('Ron DeSantis has actively tried to get the ships diverted away from the state, arguing that Florida’s hospitals cannot handle any more COVID-19 patients.',
#   4),
#  ('Remember: As stocks settle after the trading day, levels might still change slightly.',
#   4),
#  ('"At such an unprecedented and anxious time in all our lives, my wife [Camilla, Duchess of Cornwall] and I are thinking particularly of all those who have lost their loved ones in such very difficult and abnormal circumstances, and of those having to endure sickness, isolation and loneliness.',
#   4),
#  ('“None of us can say when this will end, but end it will.', 4),
#  ('Until it does, let us try and live with hope and with faith in ourselves in each other.',
#   4),
#  ('"I&aposm not actually sure, if you want to be honest, that we should carry that live.',
#   4),
#  ('And he treats the press and the media as if he&aposs talking to the people at his rallies.',
#   4),
#  ('It&aposs the same thing.', 4),
#  ('"We are not at war.', 4),
#  ('All market data delayed 20 minutes.In the midst of all of these abrupt changes, with offices and schools closed during the coronavirus outbreak, so many people are grappling with how to manage taking care of their children while also taking care of business.',
#   4),
#  ('The Associated Press contributed to this report This material may not be published, broadcast, rewritten, or redistributed.',
#   4),
#  ('“If the CDC does put out such guidance, I would respect it.', 4),
#  ('I can tell you having drafted many CDC guidelines over the years that these are done very carefully and on the best available evidence,” former CDC Chief Medical Officer Dr. Robert Amler told Fox News on Tuesday.',
#   4),
#  ('Wyoming is the only state not reporting a death from coronavirus.', 4),
#  ('Emily DeCiccio is a reporter and video producer for Fox News Digital Originals.',
#   4),
#  ('At least eight of the people onboard had tested positive for COVID-19; four “older” guests were also confirmed to have died on the Zaandam last week.',
#   4),
#  ('And we&aposre able to do both.', 4),
#  ('But the fact is that it may have to be different."', 4),
#  ('Wisconsin residents have been urged for weeks to vote by absentee ballot, which already has led to a tidal wave of demand for vote-by-mail ballots.',
#   4),
#  ("Message us on WhatsApp about the challenges you're facing: +1 347-322-0415.",
#   4),
#  ('The legislation amounts to the costliest stimulus plan in U.S. history.',
#   4),
#  ('Since then, 15 states and Puerto Rico – which were scheduled to hold their primaries and caucuses in late March, April or May –  postponed their contests or switched them to nearly entirely by mail or absentee ballot.',
#   4),
#  ('"It raised concerns about the operational security and operational capability of that ship that could have emboldened our adversaries to seek advantage and it undermined the chain of command."',
#   4),
#  ('“I think Dr. Tedros needs to step down.', 4),
#  ('We need to take some action to address this issue.', 4),
#  ('Worldwide, more than 1.2 million people have been confirmed infected and over 70,000 have died during the current coronavirus pandemic, according to Johns Hopkins University.',
#   4),
#  ('For most people, the virus causes mild to moderate symptoms such as fever and cough.',
#   4),
#  ('But for some, especially older adults and the infirm, it can cause pneumonia.',
#   4),
#  ('Over 263,000 people have recovered worldwide.', 4),
#  ('There is no known treatment, but some drugs have shown promise and patients are rushing to join studies.',
#   4),
#  ('"I am speaking to you at what I know is an increasingly challenging time," Elizabeth shared, "a time of disruption in the life of our country; a disruption that has brought grief to some, financial difficulties to many and enormous changes to the daily lives of us all."',
#   4),
#  ('"I want to thank everyone on the NHS frontline, as well as care workers and those carrying out essential roles who selflessly continue their day-to-day duties outside the home in support of us all," she said.',
#   4),
#  ('"I&aposm sure the nation will join me in ensuring you that what you do is appreciated and every hour of your hard work brings us closer to a return to more normal times."',
#   4),
#  ('Together we are tackling this disease and I want to reassure you that if we remain united in resolute then we will overcome it."',
#   4),
#  ('Elizabeth also remarked history will forever remember how the nation rose to the challenge during the crisis.',
#   4),
#  ('"The pride in who we are is not part of our past," she continued.', 4),
#  ('"It defines our present and our future.', 4),
#  ('The moments when the United Kingdom has come to applaud its care and essential workers will be remembered as an expression of our national spirit.',
#   4),
#  ('And its symbol will be the rainbows drawn by children.', 4),
#  ('Across the Commonwealth and around the world we have seen heartwarming stories of people coming together to help others.',
#   4),
#  ('Be it through delivering food parcels and medicines, checking on neighbors, or converting businesses to help the relief effort."',
#   4),
#  ('However, their efforts to flatten the curve are being recognized and honored.',
#   4),
#  ('We as children spoke from here at Windsor to children who had been evacuated from their homes and sent away for their own safety."',
#   4),
#  ('"I thought it was terrible what he did."', 4),
#  ('They need to be held accountable for their role in promoting misinformation and helping Communist China cover up a global pandemic," Scott said last week.',
#   4),
#  ('"We know Communist China is lying about how many cases and deaths they have, what they knew and when they knew it – and the WHO never bothered to investigate further."',
#   4),
#  ('It’s good that you love him.', 4),
#  ('Captain Crozier is smart and passionate."', 4),
#  ('Johnson had been quarantined in his home since being diagnosed with COVID-19 on March 26.',
#   4),
#  ('Across the Middle East and parts of South Asia, bereaved families have faced traumatic restrictions on burying their dead amid the pandemic.',
#   4),
#  ('"Hand sanitizers are great.', 3),
#  ('WHO ARE THE CORONAVIRUS VICTIMS?', 3),
#  ('Other strains, such as Severe Acute Respiratory Syndrome (SARS) and Middle East Respiratory Syndrome (MERS), can cause pneumonia and death.',
#   3),
#  ('The illness is said to be transferable between humans.', 3),
#  ('George Diaz, Section Chief of Infectious Diseases at Providence Regional Medical Center Everett, gives an update on the first patient in the United States to contract the Wuhan coronavirus.',
#   3),
#  ('Dr. Diaz explains how the virus is spread, incubation time, symptoms and warning signs.',
#   3),
#  ('Symptoms of the virus include fever, cough and shortness of breath.', 3),
#  ('We have "FOX TEAM COVERAGE".', 3),
#  ('Good evening, Chad.', 3),
#  ("Let's take a listen.", 3),
#  ('Public transit has been suspended and public venues have been closed in three cities in China; Jonathan Serrie reports.',
#   3),
#  ('WASHING HANDS KEY IN STOPPING CORONAVIRUS SPREAD: ARE YOU DOING IT CORRECTLY?',
#   3),
#  ('Fox News’ Louis Casiano and The Associated Press contributed to this report.',
#   3),
#  ('What do you say to that?', 3),
#  ('Congressman, thanks so much for coming on.', 3),
#  ("That's great.", 3),
#  ('TRACE GALLAGHER, FOX NEWS CHANNEL CHIEF BREAKING NEWS CORRESPONDENT:  Hey, Tucker.',
#   3),
#  ("Fox News' Nick Givas contributed to this report.", 3),
#  ('The U.S. patients generally have been reported to be in good condition and were hospitalized in isolation for monitoring.',
#   3),
#  ('Marc Siegel weighs in as the death toll rises in China.', 3),
#  ('National Health Minister Ma Xiaowei made the comments at a press briefing on Sunday and said that information on the virus was limited, making many risks unclear.',
#   3),
#  ('Republican Sens.', 3),
#  ("Screenings initially began for travelers arriving from Hubei at just three airports — SFO, LAX and JFK — with additional screenings implemented at O'Hare in Chicago and Hartsfield Jackson in Atlanta.",
#   3),
#  ("Fox News' Louis Casiano contributed to this report.", 3),
#  ('“Due to a significant decline in demand for travel to China, we are suspending some flights between our hub cities and Beijing, Hong Kong and Shanghai beginning Feb. 1 through Feb. 8.',
#   3),
#  ('United travelers with tickets to Wuhan through March 29 are also eligible for refunds — “even for nonrefundable tickets,” the airline writes.',
#   3),
#  ("We're happy to have her tonight.", 3),
#  ('CARLSON: Amazing.', 3),
#  ("I'm not sure.", 3),
#  ('PERINO: I know.', 3),
#  ("For starters, at this very moment, a serious viral outbreak is spreading across China, the world's biggest country.",
#   3),
#  ('Remember SARS?', 3),
#  ("Here's a look at how these two viruses affected the world.", 3),
#  ('SARS and MERS came from animals, and this newest virus almost certainly did, too.',
#   3),
#  ('What are you talking about?', 3),
#  ('GUTFELD: I know.', 3),
#  ('And you know what?', 3),
#  ("GUTFELD: That's true.", 3),
#  ("I don't understand.", 3),
#  ('Danger.', 3),
#  ('Senator, always good to have you.', 3),
#  ('After this.', 3),
#  ('GUTFELD: Wow.', 3),
#  ('China has cut off access to Wuhan, the epicenter of the outbreak, trapping more than 50 million people.',
#   3),
#  ('Air India and Seoul Air halting all flights to the country.', 3),
#  ('Finnair, Cathay Pacific, and Jetstar also stopping service.', 3),
#  ('Hello, Bret.', 3),
#  ('Good evening, welcome to Washington.', 3),
#  ('He joins us now.', 3),
#  ('Weeks after China announced the outbreak of the coronavirus, the international community has increased measures to prevent a widespread epidemic.',
#   3),
#  ('The United Kingdom announced on Friday it has two cases of the virus, who are reportedly members of the same family.',
#   3),
#  ("Pakistan says they're halting all flights to and from China until Feb. 2.",
#   3),
#  ('WATTERS: Wow.', 3),
#  ('WILLIAMS: No, no, no.', 3),
#  ('Far from it.', 3),
#  ('Oh yes.', 3),
#  ("Let's listen.", 3),
#  ("That's true.", 3),
#  ('Keep it going.', 3),
#  ('That is not true.', 3),
#  ('God bless you.', 3),
#  ('We love you.', 3),
#  ('My massive sidekick and host of "Nuff Said" on Fox Nation, Tyrus.', 3),
#  ('Come on, man.', 3),
#  ('TIMPF: Yes.', 3),
#  ('GUTFELD: All right.', 3),
#  ('COMPAGNO: Yes.', 3),
#  ('MURDOCH: Yes.', 3),
#  ("We've got more to come.", 3),
#  ('MCCARTHY: Thank you.', 3),
#  ('“A second case is not unexpected.', 3),
#  ('No deaths have been reported in the U.S. and 99 percent of cases still remain in China.',
#   3),
#  ('Currently, there are six cases of the novel coronavirus in California, one in Arizona, one in Washington state, one in Massachusetts and two in Illinois.',
#   3),
#  ('Here’s what you need to know about travel insurance just in case of the unexpected.',
#   3),
#  ('They added the U.S. was contributing to the international panic surrounding the illness, according to a report by Reuters.',
#   3),
#  ('A man wearing a face mask stands on a subway train in Beijing, Monday, Feb. 3, 2020.',
#   3),
#  ("Much of China officially went back to work on Monday after the Lunar New Year holiday was extended several days by the government due to a virus outbreak, but China's capital remained largely empty as local officials strongly encouraged non-essential businesses to remain closed or work from home.",
#   3),
#  ('The SARS outbreak had killed 349 people in mainland China back in 2002 and 2003 -- with 744 deaths and 8,096 infections globally, according to the CDC.',
#   3),
#  ('The 44-year-old Chinese man from Wuhan was hospitalized last week with a fever, cough and sore throat, and died after developing severe pneumonia, according to the Philippines health department.',
#   3),
#  ("Unlike the coronavirus, there's a seasonal vaccine for the flu.", 3),
#  ('No vaccine has been developed for coronavirus as of yet, which makes it dangerous in that respect.',
#   3),
#  ("CHINA SLAMS TRUMP'S CORONAVIRUS TRAVEL LIMITS: 'NOT A GESTURE OF GOODWILL' Officials at the CDC have advised travelers to avoid all nonessential travel to the country.",
#   3),
#  ('People wearing face masks ride a mostly empty subway train during the morning rush hour in Beijing, Monday, Feb. 3, 2020.',
#   3),
#  ('(AP Photo/Mark Schiefelbein)\n       "Those currently in China should consider departing using commercial means.',
#   3),
#  ('Carnival and Royal Carribean denying boarding of people who travel to China within 14 days.',
#   3),
#  ('Virgin Atlantic suspending operations to Shanghai for two weeks.', 3),
#  ('Thank you both.', 3),
#  ('Stay right there.', 3),
#  ('HILTON: All right.', 3),
#  ('CORONAVIRUS: HOW ARE DIFFERENT COUNTRIES RESPONDING TO THE OUTBREAK?', 3),
#  ("- Democracy 2020: Click here for Fox News' complete coverage of the presidential race.",
#   3),
#  ("That's all right.", 3),
#  ('GALLAGHER: Yes.', 3),
#  ('GALLAGHER: Sure.', 3),
#  ('Gordon, thanks so much for coming on.', 3),
#  ('We will be right back.', 3),
#  ('Currently, the U.S. has confirmed 11 cases -- six in California, one in Arizona, one in Washington state, one in Massachusetts and two in Illinois.',
#   3),
#  ("It's not entirely clear how it started, but Chinese scientists believe the virus may have originated in bats.",
#   3),
#  ('Cathay Pacific Airways asks 27,000 employees to take three weeks of unpaid leave.',
#   3),
#  ('PERINO: Yeah.', 3),
#  ('I will say this.', 3),
#  ('Welcome to Washington.', 3),
#  ('BAIER: John Roberts, live in the North Lawn.', 3),
#  ('(BEGIN VIDEO CLIP)  GOV.', 3),
#  ('An estimated 350 Americans were on the two flights.', 3),
#  ('Surgical masks, which cover the nose and mouth, are often made from a flimsy material and aren’t fitted to the face.',
#   3),
#  ...]

# %%
stop_sentences = ['contributed to this', 
                  'This material may not be published, broadcast, rewritten, or redistributed', 
                  'FOX News Network, LLC', 
                  'All rights reserved',
                  'All market data delayed',
                  'Sign up here',
                  "Get all the stories you need-to-know from the most powerful name in news delivered first thing every morning to your inbox Subscribed You've successfully subscribed to this newsletter! This material may not be published, broadcast, rewritten, or redistributed",
                  "LIMITED TIME OFFER, ",
                  r"Learn about all the*",
                  r'Get[ ]*latest[ ]*news',
                  r"delivered[ ]*daily[ ]*inbox",
                  r"Check out what's clicking[ ,\w]*",
                  r"successfully subscribed to[ ,\w]*",
                  r"Thank you for making us your first choice[ ,\w]*",
                  r"Flash top[ \w,]*headlines",
                  r"CLICK HERE*",
                  "Mobile users click here",
                  r"Fun stories about [\w,]* and more",
                  r"Stay up-to-date on the biggest [\w,]* news with our weekly recap",
                  r"originally appeared on [\w,]*",
                  r"originally published on [\w,]*",
                  r"Get a daily look at[ \w,]*",
                  "Fox Nation",
                  "The FOX NEWS RUNDOWN",
                  "subscribe and download",
                  "FOX platforms",
                  "FOX NOW",
                  "FOX NEWS APPFox News",
                  "Fox News First",
                  "copyright",
                  "Follow below on the Fox News live blog",
                  "Kim Komando Show",
                  # stop sentences from CNN
                  'Watch the latest videos on Covid-19.',
                  r'live[ ]*coverage[ ]*of[ \w]*',
                  "Note: The prices above reflect the retailer's listed price at the time of publication.",
                  "Read the full story here.",
                  r"CNN Coronavirus",
                  r"A version of this article first appeared",
                  "You can sign up for free right here",
                  "At CNN, we start with the facts.",
                  "Visit CNN's home for Facts First.",
                  "delivered to your inbox daily.",
                  "Sign up here."
                  ]
stop_sentences = [*map(lambda x: x.lower(), stop_sentences)]

# %% [markdown]
# __Delete stop sentences__

# %%
def contain_stop_sentences(sentence):
    '''
    extract the sentences that contain stop sentences
    '''
    check_status = [*map(lambda x: bool(re.search(x, sentence)), stop_sentences)]
    return(any(check_status))

# %%
def extract_no_stop_sentences(text_data):
    '''
    Applied on dataframe's column level,
    to delete the stop sentences from a whole news article
    '''
    single_news = ' '.join(''.join(text_data).lower().split('\xa0')) #exclude \xa0
    single_news_sentences = sent_tokenize(single_news)
    new_sentences = []
    for x in single_news_sentences:
        if contain_stop_sentences(x) is False:
            new_sentences.append(x)
    single_new_news = ' '.join(new_sentences)
    
    return(single_new_news)

# %%
new_news_list = df['content'].progress_apply(extract_no_stop_sentences)
df.loc[:,'true_content'] = new_news_list
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 8342/8342 [00:20<00:00, 415.67it/s]

# %% [markdown]
# ## Pre-process the text before stemming

# %%
# remove punctuations
def make_lower(text):
    return text.lower()

def remove_punctuation(text):
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text) 
    text = re.sub("\'", "", text)
    return re.sub(r'[^\w\s]', ' ', text)

def strip_extraspace(text):
    return ' '.join(text.split())

def remove_digits(text):
    return re.sub('\d', ' ', text)

def replace_word(text,word,replacement):
    return text.replace(word,replacement)

def remove_words(text,wordlist):
    for word in wordlist:
        if word in text.split():
            text = re.sub(r'\b{}\b'.format(word), '', text)  
    return text

# %%
stop_words = stopwords.words('english')
stop_words.append('coronavirus')
stop_words.append('fox')

# %%
def clean_text(text):
    text = make_lower(text)
    text = replace_word(text,'covid-19','covid') 
    text = replace_word(text,'corona virus','coronavirus') 
    text = replace_word(text,'covid','coronavirus') 
    text = replace_word(text,'fox news','fox') 
    text = replace_word(text,'new york','newyork')
    text = replace_word(text, 'begin video clip', '')
    text = replace_word(text, 'commercial break', '')
    text = remove_punctuation(text)
    text = remove_digits(text)
    text = remove_words(text,stop_words)
    
    return text

# %%
df['clean_content'] = df['true_content'].progress_apply(lambda x:clean_text(x))
data = df.clean_content.values.tolist()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 8342/8342 [01:14<00:00, 111.70it/s]

# %% [markdown]
# ## Tokenize and lemmatize words

# %% [markdown]
# __Tokenize the pre-processed words__

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# %%
data_words = list(sent_to_words(data))
data_words[:2]
# Out:
# [['early',
#   'testing',
#   'coronavirus',
#   'vaccine',
#   'likely',
#   'begin',
#   'three',
#   'months',
#   'says',
#   'dr',
#   'anthony',
#   'fauci',
#   'director',
#   'national',
#   'institute',
#   'allergy',
#   'infectious',
#   'diseases',
#   'national',
#   'institutes',
#   'health',
#   'dr',
#   'horacio',
#   'arruda',
#   'quebec',
#   'chief',
#   'public',
#   'health',
#   'officer',
#   'told',
#   'reporters',
#   'wednesday',
#   'five',
#   'people',
#   'recently',
#   'traveled',
#   'country',
#   'held',
#   'montreal',
#   'hospitals',
#   'though',
#   'not',
#   'clear',
#   'ones',
#   'sixth',
#   'person',
#   'initially',
#   'group',
#   'reportedly',
#   'discharged',
#   'testing',
#   'negative',
#   'virus',
#   'montreal',
#   'gazette',
#   'reported',
#   'confirmed',
#   'cases',
#   'arruda',
#   'assured',
#   'often',
#   'people',
#   'cold',
#   'like',
#   'went',
#   'china',
#   'went',
#   'specific',
#   'region',
#   'careful',
#   'majority',
#   'cases',
#   'negative',
#   'would',
#   'rather',
#   'act',
#   'abundance',
#   'caution',
#   'allow',
#   'case',
#   'slip',
#   'community',
#   'added',
#   'news',
#   'week',
#   'confirmed',
#   'first',
#   'case',
#   'coronavirus',
#   'seattle',
#   'man',
#   'patient',
#   'recently',
#   'traveled',
#   'wuhan',
#   'chinese',
#   'city',
#   'outbreak',
#   'first',
#   'began',
#   'proactively',
#   'reached',
#   'washington',
#   'state',
#   'health',
#   'officials',
#   'started',
#   'experiencing',
#   'symptoms',
#   'coronavirus',
#   'vaccine',
#   'early',
#   'stages',
#   'focus',
#   'turns',
#   'china',
#   'transparency',
#   'centers',
#   'disease',
#   'control',
#   'prevention',
#   'cdc',
#   'maintains',
#   'risk',
#   'public',
#   'currently',
#   'low',
#   'however',
#   'scientists',
#   'confirmed',
#   'disease',
#   'indeed',
#   'transmissible',
#   'humans'],
#  ['countries',
#   'around',
#   'world',
#   'imposed',
#   'sweeping',
#   'travel',
#   'bans',
#   'advisories',
#   'stem',
#   'spread',
#   'coronavirus',
#   'within',
#   'borders',
#   'beyond',
#   'last',
#   'week',
#   'united',
#   'states',
#   'limited',
#   'nonessential',
#   'travel',
#   'across',
#   'borders',
#   'mexico',
#   'canada',
#   'raised',
#   'global',
#   'travel',
#   'warning',
#   'americans',
#   'highest',
#   'level',
#   'advising',
#   'citizens',
#   'avoid',
#   'international',
#   'travel',
#   'countries',
#   'commercial',
#   'departure',
#   'options',
#   'remain',
#   'available',
#   'us',
#   'citizens',
#   'live',
#   'united',
#   'states',
#   'arrange',
#   'immediate',
#   'return',
#   'united',
#   'states',
#   'unless',
#   'prepared',
#   'remain',
#   'abroad',
#   'indefinite',
#   'period',
#   'us',
#   'state',
#   'department',
#   'advisory',
#   'warns',
#   'nonessential',
#   'travel',
#   'european',
#   'union',
#   'also',
#   'banned',
#   'european',
#   'council',
#   'last',
#   'week',
#   'days',
#   'united',
#   'kingdom',
#   'foreign',
#   'office',
#   'also',
#   'advised',
#   'nonessential',
#   'international',
#   'travel',
#   'days',
#   'increased',
#   'restrictions',
#   'follow',
#   'united',
#   'states',
#   'europe',
#   'travel',
#   'ban',
#   'announced',
#   'march',
#   'bars',
#   'us',
#   'entry',
#   'foreign',
#   'nationals',
#   'visited',
#   'much',
#   'europe',
#   'previous',
#   'days',
#   'flights',
#   'drastically',
#   'reduced',
#   'widespread',
#   'closures',
#   'public',
#   'areas',
#   'effect',
#   'italy',
#   'france',
#   'spain',
#   'lockdown',
#   'residents',
#   'several',
#   'us',
#   'states',
#   'including',
#   'california',
#   'newyork',
#   'stay',
#   'home',
#   'orders',
#   'travel',
#   'advisories',
#   'bans',
#   'us',
#   'state',
#   'department',
#   'global',
#   'travel',
#   'advisory',
#   'highest',
#   'level',
#   'level',
#   'not',
#   'travel',
#   'americans',
#   'advised',
#   'avoid',
#   'international',
#   'travel',
#   'detailed',
#   'country',
#   'country',
#   'list',
#   'advisories',
#   'available',
#   'state',
#   'department',
#   'website',
#   'us',
#   'centers',
#   'disease',
#   'control',
#   'prevention',
#   'list',
#   'travel',
#   'advisories',
#   'posted',
#   'online',
#   'cdc',
#   'advised',
#   'older',
#   'adults',
#   'higher',
#   'risk',
#   'groups',
#   'stay',
#   'home',
#   'much',
#   'possible',
#   'canadian',
#   'prime',
#   'minister',
#   'justin',
#   'trudeau',
#   'march',
#   'told',
#   'canadians',
#   'curtail',
#   'nonessential',
#   'travel',
#   'outside',
#   'country',
#   'canada',
#   'united',
#   'kingdom',
#   'among',
#   'many',
#   'nations',
#   'issued',
#   'travel',
#   'warnings',
#   'high',
#   'risk',
#   'destinations',
#   'addition',
#   'united',
#   'states',
#   'europe',
#   'travel',
#   'ban',
#   'restricted',
#   'us',
#   'canada',
#   'us',
#   'mexico',
#   'borders',
#   'restrictions',
#   'imposed',
#   'us',
#   'arrivals',
#   'iran',
#   'china',
#   'european',
#   'union',
#   'closed',
#   'external',
#   'borders',
#   'days',
#   'many',
#   'nations',
#   'banned',
#   'certain',
#   'arrivals',
#   'closed',
#   'borders',
#   'suspended',
#   'visas',
#   'traveling',
#   'make',
#   'sure',
#   'destination',
#   'not',
#   'restricted',
#   'arrival',
#   'embarking',
#   'keeping',
#   'mind',
#   'situation',
#   'evolving',
#   'quickly',
#   'new',
#   'restrictions',
#   'likely',
#   'travelers',
#   'avoid',
#   'contact',
#   'sick',
#   'people',
#   'clean',
#   'hands',
#   'frequently',
#   'flight',
#   'cancellations',
#   'increased',
#   'flexibility',
#   'airlines',
#   'scrambled',
#   'adapt',
#   'operations',
#   'travel',
#   'bans',
#   'staggering',
#   'drop',
#   'global',
#   'demand',
#   'american',
#   'airlines',
#   'implementing',
#   'phased',
#   'suspension',
#   'additional',
#   'international',
#   'long',
#   'haul',
#   'flights',
#   'may',
#   'move',
#   'reduce',
#   'international',
#   'capacity',
#   'year',
#   'year',
#   'details',
#   'international',
#   'route',
#   'changes',
#   'posted',
#   'airline',
#   'website',
#   'united',
#   'airlines',
#   'posted',
#   'details',
#   'safety',
#   'measures',
#   'rebooking',
#   'waivers',
#   'online',
#   'delta',
#   'air',
#   'lines',
#   'also',
#   'hub',
#   'information',
#   'online',
#   'related',
#   'impacts',
#   'coronavirus',
#   'including',
#   'details',
#   'change',
#   'fee',
#   'waivers',
#   'good',
#   'travel',
#   'march',
#   'april',
#   'tickets',
#   'booked',
#   'march',
#   'air',
#   'france',
#   'klm',
#   'carriers',
#   'across',
#   'globe',
#   'also',
#   'implemented',
#   'schedule',
#   'changes',
#   'flexible',
#   'rebooking',
#   'policies',
#   'globally',
#   'airlines',
#   'slashed',
#   'flights',
#   'amid',
#   'outbreak',
#   'many',
#   'suspending',
#   'service',
#   'hard',
#   'hit',
#   'countries',
#   'china',
#   'italy',
#   'also',
#   'slashed',
#   'domestic',
#   'service',
#   'routes',
#   'following',
#   'precipitous',
#   'drop',
#   'air',
#   'travel',
#   'travelers',
#   'upcoming',
#   'bookings',
#   'look',
#   'advisories',
#   'instructions',
#   'posted',
#   'carriers',
#   'websites',
#   'amtrak',
#   'deeply',
#   'cut',
#   'rail',
#   'service',
#   'us',
#   'drop',
#   'demand',
#   'amtrak',
#   'waiving',
#   'change',
#   'fees',
#   'existing',
#   'new',
#   'train',
#   'reservations',
#   'made',
#   'april',
#   'airline',
#   'cleaning',
#   'efforts',
#   'traveler',
#   'hygiene',
#   'airlines',
#   'bumped',
#   'sanitation',
#   'efforts',
#   'stem',
#   'virus',
#   'spread',
#   'us',
#   'centers',
#   'disease',
#   'control',
#   'prevention',
#   'posted',
#   'guidance',
#   'aircraft',
#   'cleaning',
#   'delta',
#   'air',
#   'lines',
#   'started',
#   'using',
#   'fogging',
#   'technique',
#   'february',
#   'highly',
#   'effective',
#   'epa',
#   'registered',
#   'disinfectant',
#   'flights',
#   'arriving',
#   'united',
#   'states',
#   'asia',
#   'expanded',
#   'procedure',
#   'widely',
#   'disinfecting',
#   'helpful',
#   'frequent',
#   'hand',
#   'washing',
#   'among',
#   'traveler',
#   'best',
#   'defenses',
#   'infectious',
#   'disease',
#   'experts',
#   'say',
#   'even',
#   'virus',
#   'inanimate',
#   'environment',
#   'not',
#   'going',
#   'jump',
#   'seat',
#   'bite',
#   'ankle',
#   'says',
#   'dr',
#   'william',
#   'schaffner',
#   'professor',
#   'medicine',
#   'vanderbilt',
#   'university',
#   'division',
#   'infectious',
#   'diseases',
#   'got',
#   'touch',
#   'touch',
#   'nose',
#   'mouth',
#   'hands',
#   'important',
#   'intermediary',
#   'would',
#   'put',
#   'emphasis',
#   'said',
#   'wash',
#   'sanitize',
#   'hands',
#   'touching',
#   'surfaces',
#   'airports',
#   'planes',
#   'hand',
#   'sanitizers',
#   'great',
#   'antiseptic',
#   'hand',
#   'wipes',
#   'also',
#   'use',
#   'wipe',
#   'armrests',
#   'remote',
#   'controls',
#   'seat',
#   'tray',
#   'table',
#   'said',
#   'travel',
#   'medicine',
#   'specialist',
#   'dr',
#   'richard',
#   'dawood',
#   'cdc',
#   'advises',
#   'washing',
#   'hands',
#   'often',
#   'soap',
#   'water',
#   'least',
#   'seconds',
#   'alcohol',
#   'based',
#   'hand',
#   'sanitizer',
#   'least',
#   'alcohol',
#   'used',
#   'soap',
#   'water',
#   'not',
#   'available',
#   'schaffner',
#   'received',
#   'lot',
#   'questions',
#   'whether',
#   'people',
#   'wearing',
#   'masks',
#   'avoid',
#   'infection',
#   'realizes',
#   'culturally',
#   'common',
#   'asia',
#   'says',
#   'cdc',
#   'doesn',
#   'recommend',
#   'general',
#   'public',
#   'scientific',
#   'basis',
#   'showing',
#   'people',
#   'community',
#   'wearing',
#   'masks',
#   'actually',
#   'benefit',
#   'thin',
#   'questionable',
#   'good',
#   'hand',
#   'hygiene',
#   'better',
#   'defense',
#   'sick',
#   'wearing',
#   'face',
#   'mask',
#   'around',
#   'people',
#   'helpful',
#   'according',
#   'cdc',
#   'symptomatic',
#   'avoid',
#   'travel',
#   'us',
#   'airport',
#   'screening',
#   'foreign',
#   'nationals',
#   'visited',
#   'china',
#   'iran',
#   'much',
#   'europe',
#   'past',
#   'days',
#   'barred',
#   'entering',
#   'united',
#   'states',
#   'ireland',
#   'united',
#   'kingdom',
#   'countries',
#   'schengen',
#   'area',
#   'affected',
#   'europe',
#   'ban',
#   'schengen',
#   'area',
#   'countries',
#   'austria',
#   'belgium',
#   'czech',
#   'republic',
#   'denmark',
#   'estonia',
#   'finland',
#   'france',
#   'germany',
#   'greece',
#   'hungary',
#   'iceland',
#   'italy',
#   'latvia',
#   'liechtenstein',
#   'lithuania',
#   'luxembourg',
#   'malta',
#   'netherlands',
#   'norway',
#   'poland',
#   'portugal',
#   'slovakia',
#   'slovenia',
#   'spain',
#   'sweden',
#   'switzerland',
#   'enhanced',
#   'screening',
#   'effect',
#   'american',
#   'citizens',
#   'legal',
#   'permanent',
#   'residents',
#   'returning',
#   'us',
#   'designated',
#   'high',
#   'risk',
#   'countries',
#   'travelers',
#   'required',
#   'arrive',
#   'following',
#   'us',
#   'airports',
#   'john',
#   'kennedy',
#   'international',
#   'airport',
#   'jfk',
#   'newyork',
#   'chicago',
#   'hare',
#   'international',
#   'airport',
#   'ord',
#   'illinois',
#   'san',
#   'francisco',
#   'international',
#   'airport',
#   'sfo',
#   'california',
#   'seattle',
#   'tacoma',
#   'international',
#   'airport',
#   'sea',
#   'washington',
#   'daniel',
#   'inouye',
#   'international',
#   'airport',
#   'hnl',
#   'hawaii',
#   'los',
#   'angeles',
#   'international',
#   'airport',
#   'lax',
#   'california',
#   'hartsfield',
#   'jackson',
#   'atlanta',
#   'international',
#   'airport',
#   'atl',
#   'georgia',
#   'washington',
#   'dulles',
#   'international',
#   'airport',
#   'iad',
#   'virginia',
#   'newark',
#   'liberty',
#   'international',
#   'airport',
#   'ewr',
#   'new',
#   'jersey',
#   'dallas',
#   'fort',
#   'worth',
#   'international',
#   'airport',
#   'dfw',
#   'texas',
#   'detroit',
#   'metropolitan',
#   'airport',
#   'dtw',
#   'michigan',
#   'boston',
#   'logan',
#   'international',
#   'airport',
#   'bos',
#   'miami',
#   'international',
#   'airport',
#   'mia',
#   'cruise',
#   'line',
#   'suspensions',
#   'princess',
#   'cruises',
#   'suspended',
#   'global',
#   'operations',
#   'march',
#   'may',
#   'royal',
#   'caribbean',
#   'norwegian',
#   'carnival',
#   'suspended',
#   'outbound',
#   'cruises',
#   'month',
#   'viking',
#   'temporarily',
#   'suspending',
#   'operations',
#   'river',
#   'ocean',
#   'cruises',
#   'march',
#   'april',
#   'virgin',
#   'voyages',
#   'postponed',
#   'maiden',
#   'voyage',
#   'first',
#   'cruise',
#   'ship',
#   'scarlet',
#   'lady',
#   'august',
#   'hurtigruten',
#   'known',
#   'sailings',
#   'nordic',
#   'region',
#   'including',
#   'norwegian',
#   'fjords',
#   'suspended',
#   'sailings',
#   'effective',
#   'end',
#   'april',
#   'us',
#   'state',
#   'department',
#   'issued',
#   'advisory',
#   'march',
#   'warning',
#   'cruise',
#   'travel',
#   'us',
#   'citizens',
#   'particularly',
#   'travelers',
#   'underlying',
#   'health',
#   'conditions',
#   'not',
#   'travel',
#   'cruise',
#   'ship',
#   'warning',
#   'reads',
#   'cruise',
#   'website',
#   'cruise',
#   'critic',
#   'regularly',
#   'updating',
#   'website',
#   'information',
#   'links',
#   'individual',
#   'cruise',
#   'line',
#   'policies',
#   'vacation',
#   'rental',
#   'hotel',
#   'booking',
#   'waivers',
#   'vacation',
#   'rental',
#   'giant',
#   'airbnb',
#   'expanded',
#   'extenuating',
#   'circumstances',
#   'policy',
#   'allowing',
#   'refundable',
#   'cancellations',
#   'travelers',
#   'reservations',
#   'made',
#   'march',
#   'check',
#   'dates',
#   'march',
#   'april',
#   'qualify',
#   'penalty',
#   'free',
#   'cancellations',
#   'hosts',
#   'guests',
#   'may',
#   'choose',
#   'cancel',
#   'booking',
#   'rental',
#   'company',
#   'vrbo',
#   'not',
#   'offered',
#   'coronavirus',
#   'related',
#   'exceptions',
#   'recommends',
#   'travelers',
#   'reach',
#   'homeowners',
#   'request',
#   'fee',
#   'free',
#   'cancellation',
#   'marriott',
#   'international',
#   'hotel',
#   'company',
#   'outlined',
#   'penalty',
#   'free',
#   'cancellation',
#   'rooms',
#   'including',
#   'pre',
#   'paid',
#   'hours',
#   'prior',
#   'arrival',
#   'changes',
#   'cancellations',
#   'made',
#   'april',
#   'hilton',
#   'hotels',
#   'similar',
#   'policy',
#   'check',
#   'hotel',
#   'modified',
#   'cancellation',
#   'booking',
#   'policies']]

# %% [markdown]
# __Lemmatize the tokenized words, keep only adj, noun, verb, adv__

# %%
def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
all_news = []
for one_news_list in notebook.tqdm(data_words):
    one_news = [lemmatizer.lemmatize(word, get_wordnet_pos(word)) for word in one_news_list]
    all_news.append(one_news)
    
data_lemmatized = all_news
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8342.0), HTML(value='')))

# %% [markdown]
# ## Create Bigrams for lemmatized texts

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_lemmatized, min_count=5, threshold=100) # higher threshold fewer phrases.

# Faster way to get a sentence clubbed as a bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
# Out:
# ['early', 'testing', 'coronavirus', 'vaccine', 'likely', 'begin', 'three', 'months', 'says', 'dr_anthony', 'fauci', 'director', 'national_institute', 'allergy_infectious', 'diseases', 'national', 'institutes', 'health', 'dr', 'horacio', 'arruda', 'quebec', 'chief', 'public', 'health', 'officer', 'told', 'reporters', 'wednesday', 'five', 'people', 'recently', 'traveled', 'country', 'held', 'montreal', 'hospitals', 'though', 'not', 'clear', 'ones', 'sixth', 'person', 'initially', 'group', 'reportedly', 'discharged', 'testing', 'negative', 'virus', 'montreal', 'gazette', 'reported', 'confirmed', 'cases', 'arruda', 'assured', 'often', 'people', 'cold', 'like', 'went', 'china', 'went', 'specific', 'region', 'careful', 'majority', 'cases', 'negative', 'would', 'rather', 'act', 'abundance_caution', 'allow', 'case', 'slip', 'community', 'added', 'news', 'week', 'confirmed', 'first', 'case', 'coronavirus', 'seattle', 'man', 'patient', 'recently', 'traveled', 'wuhan', 'chinese', 'city', 'outbreak', 'first', 'began', 'proactively', 'reached', 'washington', 'state', 'health', 'officials', 'started', 'experiencing', 'symptoms', 'coronavirus', 'vaccine', 'early', 'stages', 'focus', 'turns', 'china', 'transparency', 'centers', 'disease_control', 'prevention_cdc', 'maintains', 'risk', 'public', 'currently', 'low', 'however', 'scientists', 'confirmed', 'disease', 'indeed', 'transmissible', 'humans']

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

# %%
data_words_bigrams = make_bigrams(data_lemmatized)

# %% [markdown]
# ## Create the Dictionary and Corpus needed for Topic Modeling

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_words_bigrams)

# Create Corpus
texts = data_words_bigrams

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1), (5, 2), (6, 1), (7, 2), (8, 1), (9, 4), (10, 1), (11, 1), (12, 2), (13, 1), (14, 1), (15, 1), (16, 1), (17, 1), (18, 3), (19, 3), (20, 1), (21, 1), (22, 1), (23, 1), (24, 2), (25, 1), (26, 1), (27, 1), (28, 2), (29, 1), (30, 1), (31, 2), (32, 1), (33, 1), (34, 1), (35, 2), (36, 1), (37, 3), (38, 1), (39, 1), (40, 1), (41, 1), (42, 1), (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1), (51, 2), (52, 2), (53, 2), (54, 1), (55, 1), (56, 1), (57, 1), (58, 1), (59, 1), (60, 1), (61, 1), (62, 2), (63, 1), (64, 1), (65, 1), (66, 2), (67, 1), (68, 1), (69, 1), (70, 2), (71, 1), (72, 1), (73, 1), (74, 1), (75, 1), (76, 1), (77, 1), (78, 1), (79, 1), (80, 1), (81, 1), (82, 1), (83, 1), (84, 1), (85, 1), (86, 2), (87, 1), (88, 1), (89, 1), (90, 1), (91, 1), (92, 2), (93, 1), (94, 2), (95, 1), (96, 1), (97, 1), (98, 1), (99, 1), (100, 1)]]

# %%
# # Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('abundance_caution', 1),
#   ('act', 1),
#   ('add', 1),
#   ('allergy_infectious', 1),
#   ('allow', 1),
#   ('arruda', 2),
#   ('assure', 1),
#   ('begin', 2),
#   ('careful', 1),
#   ('case', 4),
#   ('center', 1),
#   ('chief', 1),
#   ('china', 2),
#   ('chinese', 1),
#   ('city', 1),
#   ('clear', 1),
#   ('cold', 1),
#   ('community', 1),
#   ('confirm', 3),
#   ('coronavirus', 3),
#   ('country', 1),
#   ('currently', 1),
#   ('director', 1),
#   ('discharge', 1),
#   ('disease', 2),
#   ('disease_control', 1),
#   ('dr', 1),
#   ('dr_anthony', 1),
#   ('early', 2),
#   ('experience', 1),
#   ('fauci', 1),
#   ('first', 2),
#   ('five', 1),
#   ('focus', 1),
#   ('gazette', 1),
#   ('go', 2),
#   ('group', 1),
#   ('health', 3),
#   ('held', 1),
#   ('horacio', 1),
#   ('hospital', 1),
#   ('however', 1),
#   ('indeed', 1),
#   ('initially', 1),
#   ('like', 1),
#   ('likely', 1),
#   ('low', 1),
#   ('maintains', 1),
#   ('majority', 1),
#   ('man', 1),
#   ('month', 1),
#   ('montreal', 2),
#   ('national_institute', 2),
#   ('negative', 2),
#   ('news', 1),
#   ('not', 1),
#   ('officer', 1),
#   ('official', 1),
#   ('often', 1),
#   ('one', 1),
#   ('outbreak', 1),
#   ('patient', 1),
#   ('people', 2),
#   ('person', 1),
#   ('prevention_cdc', 1),
#   ('proactively', 1),
#   ('public', 2),
#   ('quebec', 1),
#   ('rather', 1),
#   ('reach', 1),
#   ('recently', 2),
#   ('region', 1),
#   ('report', 1),
#   ('reportedly', 1),
#   ('reporter', 1),
#   ('risk', 1),
#   ('say', 1),
#   ('scientist', 1),
#   ('seattle', 1),
#   ('sixth', 1),
#   ('slip', 1),
#   ('specific', 1),
#   ('stage', 1),
#   ('start', 1),
#   ('state', 1),
#   ('symptom', 1),
#   ('test', 2),
#   ('though', 1),
#   ('three', 1),
#   ('told', 1),
#   ('transmissible_human', 1),
#   ('transparency', 1),
#   ('travel', 2),
#   ('turn', 1),
#   ('vaccine', 2),
#   ('virus', 1),
#   ('washington', 1),
#   ('wednesday', 1),
#   ('week', 1),
#   ('would', 1),
#   ('wuhan', 1)]]

# %% [markdown]
# # Building LDA Mallet Model

# %%
# train the ldamallet model
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=5, id2word=id2word)

# %%
# Show Topics
print(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_words_bigrams, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(0,
#   [('time', 0.011850236277717193),
#    ('coronavirus', 0.010972633328140417),
#    ('home', 0.010087241003271538),
#    ('aposs', 0.01004829412681103),
#    ('family', 0.009048657630991329),
#    ('year', 0.007745235498779665),
#    ('people', 0.007444046320818404),
#    ('day', 0.00658202212182583),
#    ('show', 0.005673261671080646),
#    ('make', 0.005662875837357844)]),
#  (1,
#   [('coronavirus', 0.03750557699721475),
#    ('health', 0.017926526581159927),
#    ('test', 0.015632918794588904),
#    ('people', 0.01497450824962423),
#    ('virus', 0.014747096712712088),
#    ('hospital', 0.01210912288453125),
#    ('patient', 0.011907701237551926),
#    ('care', 0.0101490520187647),
#    ('newyork', 0.009943298723463239),
#    ('medical', 0.00991947465769149)]),
#  (2,
#   [('coronavirus', 0.014050741204390675),
#    ('company', 0.00837389375184274),
#    ('week', 0.007996887279898305),
#    ('business', 0.007450711237209572),
#    ('work', 0.007397543657832793),
#    ('pandemic', 0.007025370602195337),
#    ('make', 0.006283441199073918),
#    ('million', 0.006254440701232038),
#    ('worker', 0.00609735467125519),
#    ('include', 0.005783182611301494)]),
#  (3,
#   [('coronavirus', 0.02980871603076839),
#    ('case', 0.02010907113142924),
#    ('state', 0.01680375806116299),
#    ('health', 0.012288876802540092),
#    ('china', 0.012215378735539255),
#    ('report', 0.011049909387383112),
#    ('official', 0.01056272220040613),
#    ('country', 0.01040522634254719),
#    ('virus', 0.010365327391889593),
#    ('outbreak', 0.009504350035594064)]),
#  (4,
#   [('trump', 0.025161974816920972),
#    ('president', 0.021689372878787007),
#    ('people', 0.010410131555975081),
#    ('state', 0.008564472404325979),
#    ('american', 0.007856522064452259),
#    ('make', 0.006369634494256777),
#    ('thing', 0.006191207985833319),
#    ('time', 0.005861214873480257),
#    ('call', 0.005586860134721607),
#    ('biden', 0.005425700707758483)])]
#
# Coherence Score:  0.4234528696835427

# %% [markdown]
# ## Find the optimal number of topics for LDA

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_words_bigrams, start=3, limit=21, step=3)

# %%
# Show elbow graph
import matplotlib.pyplot as plt
# %matplotlib inline

limit=21; start=3; step=3;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %%
# select the model based on the coherence-score elbow-plot 
optimal_model = model_list[4]
filename = 'foxcnn_model.sav'
pickle.dump(optimal_model, open(filename, 'wb'))
optimal_model = joblib.load(filename)

# %%
# Select the model and print the topics
model_topics = optimal_model.show_topics(formatted=False)
print("Topics for the chosen LDA model:\n")
pprint(optimal_model.print_topics(num_words=10))
# Out:
# Topics for the chosen LDA model:
#
# [(0,
#   '0.008*"call" + 0.008*"report" + 0.007*"medium" + 0.007*"write" + '
#   '0.007*"year" + 0.007*"claim" + 0.006*"charge" + 0.006*"news" + '
#   '0.006*"tweet" + 0.006*"law"'),
#  (1,
#   '0.039*"hospital" + 0.039*"newyork" + 0.025*"medical" + 0.021*"care" + '
#   '0.018*"state" + 0.018*"patient" + 0.017*"city" + 0.017*"mask" + '
#   '0.016*"health" + 0.012*"case"'),
#  (2,
#   '0.028*"trump" + 0.023*"biden" + 0.021*"president" + 0.021*"state" + '
#   '0.016*"campaign" + 0.013*"sander" + 0.013*"democratic" + 0.012*"election" + '
#   '0.011*"primary" + 0.010*"vote"'),
#  (3,
#   '0.056*"china" + 0.019*"travel" + 0.019*"chinese" + 0.018*"outbreak" + '
#   '0.017*"report" + 0.016*"case" + 0.014*"virus" + 0.013*"health" + '
#   '0.013*"official" + 0.013*"wuhan"'),
#  (4,
#   '0.027*"country" + 0.024*"people" + 0.017*"case" + 0.014*"italy" + '
#   '0.012*"death" + 0.012*"virus" + 0.010*"government" + 0.010*"number" + '
#   '0.009*"report" + 0.009*"iran"'),
#  (5,
#   '0.042*"aposs" + 0.022*"time" + 0.014*"life" + 0.013*"pandemic" + '
#   '0.013*"family" + 0.013*"child" + 0.012*"apos" + 0.010*"news_deliver" + '
#   '0.010*"apost" + 0.010*"people"'),
#  (6,
#   '0.030*"people" + 0.017*"thing" + 0.012*"lot" + 0.012*"make" + '
#   '0.012*"president" + 0.011*"talk" + 0.011*"time" + 0.010*"good" + '
#   '0.009*"back" + 0.009*"today"'),
#  (7,
#   '0.057*"trump" + 0.045*"president" + 0.022*"american" + 0.016*"response" + '
#   '0.015*"state" + 0.015*"pandemic" + 0.014*"country" + 0.014*"white_house" + '
#   '0.013*"virus" + 0.013*"administration"'),
#  (8,
#   '0.026*"test_positive" + 0.021*"test" + 0.020*"day" + 0.014*"told" + '
#   '0.014*"member" + 0.012*"family" + 0.011*"symptom" + 0.011*"march" + '
#   '0.011*"report" + 0.010*"health"'),
#  (9,
#   '0.039*"state" + 0.020*"order" + 0.018*"people" + 0.018*"home" + '
#   '0.018*"health" + 0.015*"close" + 0.015*"stay" + 0.014*"public" + '
#   '0.011*"official" + 0.011*"city"'),
#  (10,
#   '0.016*"company" + 0.012*"make" + 0.012*"food" + 0.012*"work" + '
#   '0.009*"employee" + 0.008*"worker" + 0.008*"restaurant" + 0.007*"provide" + '
#   '0.006*"pandemic" + 0.006*"service"'),
#  (11,
#   '0.019*"bill" + 0.014*"house" + 0.012*"senate" + 0.010*"american" + '
#   '0.010*"business" + 0.008*"billion" + 0.008*"democrat" + 0.008*"million" + '
#   '0.008*"republican" + 0.008*"economic"'),
#  (12,
#   '0.014*"show" + 0.010*"write" + 0.010*"star" + 0.010*"home" + 0.009*"video" '
#   '+ 0.009*"post" + 0.009*"share" + 0.008*"love" + 0.008*"year" + '
#   '0.007*"photo"'),
#  (13,
#   '0.019*"team" + 0.017*"season" + 0.016*"game" + 0.015*"player" + '
#   '0.014*"event" + 0.013*"year" + 0.011*"cancel" + 0.010*"play" + '
#   '0.009*"sport" + 0.009*"time"'),
#  (14,
#   '0.030*"virus" + 0.020*"test" + 0.018*"health" + 0.018*"people" + '
#   '0.013*"patient" + 0.011*"spread" + 0.011*"dr" + 0.011*"risk" + '
#   '0.011*"disease" + 0.010*"drug"')]

# %% [markdown]
# ## Finding the dominant topic in each sentence

# %%
def format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel = optimal_model, corpus = corpus, texts = data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']
df_dominant_topic.sample(10)
df_dominant_topic.to_excel('LDA_foxcnn_colab.xlsx', index = False)

# %%
df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# %%
# Show
df_dominant_topic.sample(10)
# Out:
#       Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 4550         4550            14.0              0.5363
# 1693         1693            14.0              0.6054
# 4099         4099            12.0              0.3026
# 541           541             8.0              0.4935
# 6011         6011             6.0              0.4136
# 4104         4104             1.0              0.3400
# 3785         3785            13.0              0.2698
# 3929         3929             5.0              0.4221
# 4180         4180             8.0              0.2755
# 4450         4450            11.0              0.2030
#
#                                                Keywords  \
# 4550  virus, test, health, people, patient, spread, ...
# 1693  virus, test, health, people, patient, spread, ...
# 4099  show, write, star, home, video, post, share, l...
# 541   test_positive, test, day, told, member, family...
# 6011  people, thing, lot, make, president, talk, tim...
# 4104  hospital, newyork, medical, care, state, patie...
# 3785  team, season, game, player, event, year, cance...
# 3929  aposs, time, life, pandemic, family, child, ap...
# 4180  test_positive, test, day, told, member, family...
# 4450  bill, house, senate, american, business, billi...
#
#                                                    Text
# 4550  acting homeland security secretary chad wolf j...
# 1693  get   latest news     delivered daily   inbox ...
# 4099   top    theater chains   u    shut  doors     ...
# 541   get   latest news     delivered daily   inbox ...
# 6011  moderate democrat neal urwitz says   not want ...
# 4104  veterans affairs secretary robert wilkie weigh...
# 3785   nba suspended          season last week   pla...
# 3929  thousands  schools  closed across  country due...
# 4180    lot  folks  talked      quarantine situation...
# 4450  president trump announces  expansion  medicare...

# %%
df_dominant_topic.to_excel('LDA_foxcnn_colab.xlsx', index = False)

# %% [markdown]
# ## Find the most representative document for each topic

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet
# Out:
#     Topic_Num  Topic_Perc_Contrib  \
# 0         0.0              0.5656
# 1         1.0              0.6287
# 2         2.0              0.7436
# 3         3.0              0.7096
# 4         4.0              0.6155
# 5         5.0              0.6271
# 6         6.0              0.6489
# 7         7.0              0.4701
# 8         8.0              0.7656
# 9         9.0              0.6646
# 10       10.0              0.6904
# 11       11.0              0.7250
# 12       12.0              0.6461
# 13       13.0              0.7612
# 14       14.0              0.6884
#
#                                              Keywords  \
# 0   call, report, medium, write, year, claim, char...
# 1   hospital, newyork, medical, care, state, patie...
# 2   trump, biden, president, state, campaign, sand...
# 3   china, travel, chinese, outbreak, report, case...
# 4   country, people, case, italy, death, virus, go...
# 5   aposs, time, life, pandemic, family, child, ap...
# 6   people, thing, lot, make, president, talk, tim...
# 7   trump, president, american, response, state, p...
# 8   test_positive, test, day, told, member, family...
# 9   state, order, people, home, health, close, sta...
# 10  company, make, food, work, employee, worker, r...
# 11  bill, house, senate, american, business, billi...
# 12  show, write, star, home, video, post, share, l...
# 13  team, season, game, player, event, year, cance...
# 14  virus, test, health, people, patient, spread, ...
#
#                                                  Text
# 0   new findings   justice department inspector ge...
# 1   u   navy hospital ship docked  port  los angel...
# 2   former vice president joe biden says america n...
# 3     disease  spread     countries  global financ...
# 4    country bans  outside activities  including e...
# 5   psychotherapist  author dr  robi ludwig shares...
# 6   joe biden benefits   democrat party  political...
# 7   get   latest news     delivered daily   inbox ...
# 8   buckingham palace says queen elizabeth   good ...
# 9       participating  social distancing    pandem...
# 10  many restaurant chains  altering  services   p...
# 11  democrats  republicans battle   stimulus bill ...
# 12  film expert  turner classic movies  tcm  host ...
# 13   ivy league men  basketball tournament begins ...
# 14  \n  friday  nov           photo   rhesus macaq...

# %%
sent_topics_sorteddf_mallet.to_excel('LDA_foxcnn_colab_rep.xlsx', index = False)

# %%
# Number of Documents for Each Topic
topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# Percentage of Documents for Each Topic
topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# Topic Number and Keywords
topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']].drop_duplicates()
topic_num_keywords = topic_num_keywords.set_index('Dominant_Topic')

# %%
# Concatenate Column wise
df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# Change Column names
df_dominant_topics.columns = ['Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# Show
df_dominant_topics
# Out:
#                                          Topic_Keywords  Num_Documents  \
# 0.0   call, report, medium, write, year, claim, char...            290
# 1.0   hospital, newyork, medical, care, state, patie...            428
# 2.0   trump, biden, president, state, campaign, sand...            298
# 3.0   china, travel, chinese, outbreak, report, case...            597
# 4.0   country, people, case, italy, death, virus, go...            480
# 5.0   aposs, time, life, pandemic, family, child, ap...            301
# 6.0   people, thing, lot, make, president, talk, tim...            172
# 7.0   trump, president, american, response, state, p...            491
# 8.0   test_positive, test, day, told, member, family...            302
# 9.0   state, order, people, home, health, close, sta...            474
# 10.0  company, make, food, work, employee, worker, r...            520
# 11.0  bill, house, senate, american, business, billi...            469
# 12.0  show, write, star, home, video, post, share, l...            683
# 13.0  team, season, game, player, event, year, cance...            570
# 14.0  virus, test, health, people, patient, spread, ...            573
#
#       Perc_Documents
# 0.0           0.0436
# 1.0           0.0644
# 2.0           0.0448
# 3.0           0.0898
# 4.0           0.0722
# 5.0           0.0453
# 6.0           0.0259
# 7.0           0.0739
# 8.0           0.0454
# 9.0           0.0713
# 10.0          0.0782
# 11.0          0.0705
# 12.0          0.1027
# 13.0          0.0857
# 14.0          0.0862

# %%
df_dominant_topics.sort_values('Num_Documents', ascending = False).to_excel('LDA_foxcnn_colab_topics.xlsx', index = True)

# %%
pprint(df_dominant_topics.Topic_Keywords)
# Out:
# 0.0     call, report, medium, write, year, claim, char...
# 1.0     hospital, newyork, medical, care, state, patie...
# 2.0     trump, biden, president, state, campaign, sand...
# 3.0     china, travel, chinese, outbreak, report, case...
# 4.0     country, people, case, italy, death, virus, go...
# 5.0     aposs, time, life, pandemic, family, child, ap...
# 6.0     people, thing, lot, make, president, talk, tim...
# 7.0     trump, president, american, response, state, p...
# 8.0     test_positive, test, day, told, member, family...
# 9.0     state, order, people, home, health, close, sta...
# 10.0    company, make, food, work, employee, worker, r...
# 11.0    bill, house, senate, american, business, billi...
# 12.0    show, write, star, home, video, post, share, l...
# 13.0    team, season, game, player, event, year, cance...
# 14.0    virus, test, health, people, patient, spread, ...
# Name: Topic_Keywords, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Topic Trending Viz

# %%
df.head()
# Out:
#              true_time                                           headline  \
# 0  2020-04-09 00:00:00  Wife of Edmonton Oilers' Colby Cave gives upda...
# 1  2020-04-09 00:00:00  Body of RFK granddaughter’s son, 8, recovered ...
# 2  2020-04-09 00:00:00  Hundreds of inmates at Washington state correc...
# 3  2020-04-09 00:00:00  Nikki Haley, in op-ed, says coronavirus respon...
# 4  2020-04-09 00:00:00  Barr disappointed by partisan attacks leveled ...
#
#                                                 link  \
# 0  https://www.foxnews.com/sports/wife-of-edmonto...
# 1  https://www.foxnews.com/us/body-of-rfk-grandda...
# 2  https://www.foxnews.com/us/hundreds-of-inmates...
# 3  https://www.foxnews.com/politics/nikki-haley-i...
# 4  https://www.foxnews.com/media/ag-william-barr-...
#
#                                              summary  \
# 0  The wife of Edmonton Oilers forward Colby Cave...
# 1  The body of 8-year-old Gideon McKean was recov...
# 2  Authorities in Washington state responded late...
# 3  Responsibility for combating the coronavirus o...
# 4  Attorney General William Barr told "The Ingrah...
#
#                                              content  \
# 0  The wife of Edmonton Oilers forward Colby Cave...
# 1  The body of 8-year-old Gideon McKean was recov...
# 2  Get all the latest news on coronavirus and mor...
# 3  Get all the latest news on coronavirus and mor...
# 4  Get all the latest news on coronavirus and mor...
#
#                                         true_content  \
# 0  the wife of edmonton oilers forward colby cave...
# 1  the body of 8-year-old gideon mckean was recov...
# 2  get all the latest news on coronavirus and mor...
# 3  get all the latest news on coronavirus and mor...
# 4  get all the latest news on coronavirus and mor...
#
#                                        clean_content
# 0   wife  edmonton oilers forward colby cave wedn...
# 1   body    year old gideon mckean  recovered wed...
# 2  get   latest news     delivered daily   inbox ...
# 3  get   latest news     delivered daily   inbox ...
# 4  get   latest news     delivered daily   inbox ...

# %%
df_dominant_topic_date = pd.concat([df['true_time'].reset_index(), df_dominant_topic], axis = 1)
df_dominant_topic_date.head()
# Out:
#    index            true_time  Document_No  Dominant_Topic  \
# 0      0  2020-04-09 00:00:00            0            13.0
# 1      1  2020-04-09 00:00:00            1             5.0
# 2      2  2020-04-09 00:00:00            2             0.0
# 3      3  2020-04-09 00:00:00            3             7.0
# 4      4  2020-04-09 00:00:00            4             7.0
#
#    Topic_Perc_Contrib                                           Keywords  \
# 0              0.2454  team, season, game, player, event, year, cance...
# 1              0.2825  aposs, time, life, pandemic, family, child, ap...
# 2              0.1826  call, report, medium, write, year, claim, char...
# 3              0.3467  trump, president, american, response, state, p...
# 4              0.1651  trump, president, american, response, state, p...
#
#                                                 Text
# 0   wife  edmonton oilers forward colby cave wedn...
# 1   body    year old gideon mckean  recovered wed...
# 2  get   latest news     delivered daily   inbox ...
# 3  get   latest news     delivered daily   inbox ...
# 4  get   latest news     delivered daily   inbox ...

# %%
df_dominant_topic_date
# Out:
#       index            true_time  Document_No  Dominant_Topic  \
# 0         0  2020-04-09 00:00:00            0            13.0
# 1         1  2020-04-09 00:00:00            1             5.0
# 2         2  2020-04-09 00:00:00            2             0.0
# 3         3  2020-04-09 00:00:00            3             7.0
# 4         4  2020-04-09 00:00:00            4             7.0
# ...     ...                  ...          ...             ...
# 6643   6899  2020-01-23 00:00:00         6643             3.0
# 6644   6900  2020-01-23 00:00:00         6644             3.0
# 6645   6901  2020-01-23 00:00:00         6645             0.0
# 6646   6902  2020-01-23 00:00:00         6646             3.0
# 6647   6903  2020-01-23 00:00:00         6647            11.0
#
#       Topic_Perc_Contrib                                           Keywords  \
# 0                 0.2454  team, season, game, player, event, year, cance...
# 1                 0.2825  aposs, time, life, pandemic, family, child, ap...
# 2                 0.1826  call, report, medium, write, year, claim, char...
# 3                 0.3467  trump, president, american, response, state, p...
# 4                 0.1651  trump, president, american, response, state, p...
# ...                  ...                                                ...
# 6643              0.2335  china, travel, chinese, outbreak, report, case...
# 6644              0.2840  china, travel, chinese, outbreak, report, case...
# 6645              0.2596  call, report, medium, write, year, claim, char...
# 6646              0.3642  china, travel, chinese, outbreak, report, case...
# 6647              0.1589  bill, house, senate, american, business, billi...
#
#                                                    Text
# 0      wife  edmonton oilers forward colby cave wedn...
# 1      body    year old gideon mckean  recovered wed...
# 2     get   latest news     delivered daily   inbox ...
# 3     get   latest news     delivered daily   inbox ...
# 4     get   latest news     delivered daily   inbox ...
# ...                                                 ...
# 6643  dr  mehmet oz reacts  china quarantining  epic...
# 6644  infectious disease expert dr  amesh adalja    ...
# 6645   two days  debate  twitter exploded  blisterin...
# 6646  public transit   suspended  public venues   cl...
# 6647     friends       et  special guests include  d...
#
# [6648 rows x 7 columns]

# %%
df_dominant_topic_date.to_excel('foxcnn_dominant_topic_date.xlsx', index = False)

# %%
# df_dominant_topic_date.groupby(['true_time','Dominant_Topic']).agg('count')
agg_topicandtime = pd.pivot_table(df_dominant_topic_date, index=['true_time'], values = ['Document_No'], columns = ['Dominant_Topic'], aggfunc = 'count')
agg_topicandtime.to_excel('foxcnn_agg_topicandtime.xlsx')
